# %% [markdown]
# # Notebook para la pregunta 4.3 sobre el reconocimiento de escenas con Redes Convolucionales Neuronales

# %% [markdown]
# # 1.Preparación del entorno de trabajo como en los notebooks anteriores

# %%
#%%capture
#%tensorflow_version 2.x
# !pip install tensorflow==2.3.0
import tensorflow as tf
import os, subprocess
# !python --version                     # mostrar version de python
print('Tensorflow ' + tf.__version__) # mostrar version tensorflow
# Out:
# Collecting tensorflow==2.3.0
#   Downloading tensorflow-2.3.0-cp37-cp37m-manylinux2010_x86_64.whl (320.4 MB)
#      |████████████████████████████████| 320.4 MB 55 kB/s
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Downloading tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
#      |████████████████████████████████| 459 kB 24.5 MB/s
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (2.7.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.2.0)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.13.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.37.0)
# Collecting numpy<1.19.0,>=1.16.0
#   Downloading numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 12.1 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.42.0)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 17.7 MB/s
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.15.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.3.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.4.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.17.3)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.8.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.35.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.10.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.1)
# Installing collected packages: numpy, tensorflow-estimator, h5py, gast, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed gast-0.3.3 h5py-2.10.0 numpy-1.18.5 tensorflow-2.3.0 tensorflow-estimator-2.3.0
# Python 3.7.12
# Tensorflow 2.3.0

# %% [markdown]
# # 2.Creación y almacenamiento de los datos

# %%
import os, subprocess

# Montar Google Drive y crear carpetas
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

work_dir = '/content/work_dir'                    # directorio de trabajo en local (mas rapido)
dwld_dir = '/content/gdrive/My Drive/dwld_dir'    # directorio de descarga en Google drive personal
subprocess.call(["mkdir","-p",work_dir])          # crear directorio para trabajo
subprocess.call(["mkdir","-p",dwld_dir+'/dataset/'])  # crear directorio para dataset

os.chdir(dwld_dir+'/dataset/')                        # posicionarse en el directorio
# Descargar dataset scenes15 si no esta disponible
if os.path.isfile('./dataset_scenes15.zip') == False: 
  # !wget http://www-vpu.eps.uam.es/~jcs/tsv/dataset_scenes15.zip 
  
# Copiar el dataset al directorio local (mayor velocidad de lectura que en Gdrive)
# !cp /content/gdrive/My\ Drive/dwld_dir/dataset/dataset_scenes15.zip /content/work_dir/

os.chdir(work_dir)                        # posicionarse en el directorio
if os.path.isdir('./scenes15') == False: 
  # !unzip -o -q dataset_scenes15.zip -d .

print('El dataset se encuentra descargado en el directorio {} \ny descomprimido en el directorio {} (usado para lectura de datos)'.format(dwld_dir, work_dir))
# Out:
# Mounted at /content/gdrive
# El dataset se encuentra descargado en el directorio /content/gdrive/My Drive/dwld_dir
# y descomprimido en el directorio /content/work_dir (usado para lectura de datos)

# %% [markdown]
# # 3.Seleccionamos Hardware como en ejemplos previos

# %%
import tensorflow as tf
import time

print("Num CPUs disponibles: ", len(tf.config.experimental.list_physical_devices('CPU')))
print("Num GPUs disponibles: ", len(tf.config.experimental.list_physical_devices('GPU')))

time1 = time.time() # medida de tiempo

# ejecutar en CPU
with tf.device('/CPU:0'):
  random_image_cpu = tf.random.normal((100, 100, 100, 3))
  net_cpu = tf.keras.layers.Conv2D(128, 7)(random_image_cpu)

time2 = time.time() # medida de tiempo

# ejecutar en GPU
with tf.device('/device:GPU:0'):
  random_image_cpu = tf.random.normal((100, 100, 100, 3))
  net_cpu = tf.keras.layers.Conv2D(128, 7)(random_image_cpu)

time3 = time.time() # medida de tiempo
print('Tiempo ejecución CPU {} secs y GPU {} secs' .format(time2-time1, time3-time2))
print('Ejecute varias veces este bloque de código pues la primera vez no observará diferencias debido a que se deben inicializar los registros para la CPU y GPU')
# Out:
# Num CPUs disponibles:  1
# Num GPUs disponibles:  1
# Tiempo ejecución CPU 1.7918028831481934 secs y GPU 3.4559574127197266 secs
# Ejecute varias veces este bloque de código pues la primera vez no observará diferencias debido a que se deben inicializar los registros para la CPU y GPU

# %% [markdown]
# # 4.Crear iterador para los datos del dataset, definición del modelo, optimización de parámetros, entrenamiento y clasificación

# %%
import tensorflow as tf
import pathlib
import numpy as np
import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
import tensorflow.keras.optimizers as optimizers
import matplotlib.pyplot as plt

list_activation = ['linear', 'tanh', 'relu', 'sigmoid']
accs = []
val_accs = []
losses = []
val_losses = []

for activation in list_activation:

  dataset_dir = pathlib.Path(work_dir + '/scenes15/')

  # Obtener etiquetas de clase y numero de clases
  CLASS_NAMES = np.array([item.name for item in dataset_dir.glob('*')]) #clases son subdirectorios de '/train/'
  NUM_CLASSES = len(CLASS_NAMES) # numero total de clases
 
  # Crear ImageDataGenerator convirtiendo de uint8 a float32 en el rango [0,1].
  img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20)

  # Obtenemos un iterador sobre los datos de entrenamiento del dataset
  # aplicando el ImageDataGenerator creado anteriormente
  BATCH_SIZE = 32 # numero de elementos procesados conjuntamente en cada iteracion
  IMG_HEIGHT = 32
  IMG_WIDTH = 32
  IMG_CHANNELS = 3

  train_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',                                                     
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE, 
                                            subset="training",                                         
                                            shuffle=True,
                                            seed=0)

  test_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',                                                     
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="validation",
                                            shuffle=True,
                                            seed=0)
  
  # definir modelo de red
  model = models.Sequential()

  # incluir capa convolucional C1
  model.add(layers.Conv2D(filters=6, 
                          kernel_size=(3, 3), 
                          strides = (1,1),
                          padding = 'valid',
                          activation=activation, 
                          input_shape=(IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)))

  # incluir average pooling S2
  model.add(layers.AveragePooling2D())

  # incluir capa convolucional C3
  model.add(layers.Conv2D(filters=16, 
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid', 
                          activation=activation))

  # incluir average pooling S4
  model.add(layers.AveragePooling2D())

  # convertir el volumen de datos en vector fila para conectarlo con capa FC
  model.add(layers.Flatten())

  # incluir fully convolutional F5
  model.add(layers.Dense(units=120, activation=activation))

  # incluir fully convolutional F6
  model.add(layers.Dense(units=84, activation=activation))

  # incluir salida OUTPUT
  model.add(layers.Dense(units=NUM_CLASSES, activation = 'softmax'))

  LEARNING_RATE = 0.01 # factor de aprendizaje
  model.compile(optimizer=optimizers.SGD(lr=LEARNING_RATE),            
            loss='categorical_crossentropy',            
            metrics=['accuracy'])
  
  EPOCHS = 25 # numero de epocas para entrenamiento

  #si tiene problemas al ejecutar con la GPU, 
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    history = model.fit_generator(
        generator=train_data_gen,          
        steps_per_epoch=train_data_gen.n // BATCH_SIZE,      
        validation_data=test_data_gen,
        validation_steps=test_data_gen.n // BATCH_SIZE,
        epochs=EPOCHS,
        verbose=1     
    )  

  #si tiene problemas al ejecutar con la GPU, 
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    test_loss, test_acc = model.evaluate_generator(generator=test_data_gen, 
                                                  steps = test_data_gen.n // BATCH_SIZE, 
                                                  verbose=1)
  accs.append(history.history['accuracy']) 
  val_accs.append(history.history['val_accuracy'])
  losses.append(history.history['loss'])
  val_losses.append(history.history['val_loss'])
# Out:
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# WARNING:tensorflow:From <ipython-input-3-df4ef8cab560>:107: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/25
# 112/112 [==============================] - 5s 46ms/step - loss: 2.6858 - accuracy: 0.1129 - val_loss: 2.6406 - val_accuracy: 0.1042
# Epoch 2/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.6128 - accuracy: 0.1351 - val_loss: 2.6068 - val_accuracy: 0.1412
# Epoch 3/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.5615 - accuracy: 0.1618 - val_loss: 2.5775 - val_accuracy: 0.1262
# Epoch 4/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.5223 - accuracy: 0.1680 - val_loss: 2.5623 - val_accuracy: 0.1771
# Epoch 5/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.4913 - accuracy: 0.1857 - val_loss: 2.5663 - val_accuracy: 0.1678
# Epoch 6/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.4639 - accuracy: 0.1919 - val_loss: 2.5383 - val_accuracy: 0.1933
# Epoch 7/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.4415 - accuracy: 0.2101 - val_loss: 2.5302 - val_accuracy: 0.1910
# Epoch 8/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.4219 - accuracy: 0.2157 - val_loss: 2.5211 - val_accuracy: 0.1887
# Epoch 9/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.4037 - accuracy: 0.2222 - val_loss: 2.5041 - val_accuracy: 0.2060
# Epoch 10/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.3859 - accuracy: 0.2306 - val_loss: 2.5012 - val_accuracy: 0.2106
# Epoch 11/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.3738 - accuracy: 0.2315 - val_loss: 2.4967 - val_accuracy: 0.1944
# Epoch 12/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.3647 - accuracy: 0.2388 - val_loss: 2.5050 - val_accuracy: 0.2083
# Epoch 13/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3610 - accuracy: 0.2376 - val_loss: 2.4850 - val_accuracy: 0.2118
# Epoch 14/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3519 - accuracy: 0.2438 - val_loss: 2.5184 - val_accuracy: 0.1968
# Epoch 15/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3454 - accuracy: 0.2421 - val_loss: 2.4940 - val_accuracy: 0.2130
# Epoch 16/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3365 - accuracy: 0.2517 - val_loss: 2.5068 - val_accuracy: 0.1968
# Epoch 17/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3371 - accuracy: 0.2534 - val_loss: 2.5178 - val_accuracy: 0.2002
# Epoch 18/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3354 - accuracy: 0.2522 - val_loss: 2.5050 - val_accuracy: 0.2072
# Epoch 19/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3246 - accuracy: 0.2621 - val_loss: 2.4914 - val_accuracy: 0.2072
# Epoch 20/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.3223 - accuracy: 0.2601 - val_loss: 2.5276 - val_accuracy: 0.1875
# Epoch 21/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.3145 - accuracy: 0.2579 - val_loss: 2.5138 - val_accuracy: 0.1968
# Epoch 22/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.3113 - accuracy: 0.2711 - val_loss: 2.5205 - val_accuracy: 0.1944
# Epoch 23/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.3074 - accuracy: 0.2635 - val_loss: 2.5331 - val_accuracy: 0.1875
# Epoch 24/25
# 112/112 [==============================] - 4s 39ms/step - loss: 2.3021 - accuracy: 0.2632 - val_loss: 2.5157 - val_accuracy: 0.2072
# Epoch 25/25
# 112/112 [==============================] - 4s 39ms/step - loss: 2.3010 - accuracy: 0.2725 - val_loss: 2.5118 - val_accuracy: 0.1898
# WARNING:tensorflow:From <ipython-input-3-df4ef8cab560>:117: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# 27/27 [==============================] - 1s 31ms/step - loss: 2.5109 - accuracy: 0.1910
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6895 - accuracy: 0.0809 - val_loss: 2.6789 - val_accuracy: 0.0938
# Epoch 2/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6650 - accuracy: 0.0975 - val_loss: 2.6679 - val_accuracy: 0.0856
# Epoch 3/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6414 - accuracy: 0.1132 - val_loss: 2.6461 - val_accuracy: 0.0880
# Epoch 4/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6130 - accuracy: 0.1379 - val_loss: 2.6248 - val_accuracy: 0.1250
# Epoch 5/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.5790 - accuracy: 0.1573 - val_loss: 2.6047 - val_accuracy: 0.1470
# Epoch 6/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.5434 - accuracy: 0.1725 - val_loss: 2.5766 - val_accuracy: 0.1562
# Epoch 7/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.5040 - accuracy: 0.1933 - val_loss: 2.5570 - val_accuracy: 0.1817
# Epoch 8/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.4706 - accuracy: 0.1938 - val_loss: 2.5416 - val_accuracy: 0.1725
# Epoch 9/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.4468 - accuracy: 0.2110 - val_loss: 2.5283 - val_accuracy: 0.1713
# Epoch 10/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.4290 - accuracy: 0.2194 - val_loss: 2.5180 - val_accuracy: 0.1794
# Epoch 11/25
# 112/112 [==============================] - 5s 40ms/step - loss: 2.4107 - accuracy: 0.2225 - val_loss: 2.5240 - val_accuracy: 0.1725
# Epoch 12/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.4037 - accuracy: 0.2239 - val_loss: 2.5095 - val_accuracy: 0.1921
# Epoch 13/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.3871 - accuracy: 0.2326 - val_loss: 2.5025 - val_accuracy: 0.1875
# Epoch 14/25
# 112/112 [==============================] - 4s 40ms/step - loss: 2.3771 - accuracy: 0.2343 - val_loss: 2.5049 - val_accuracy: 0.2014
# Epoch 15/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.3675 - accuracy: 0.2399 - val_loss: 2.5012 - val_accuracy: 0.1863
# Epoch 16/25
# 112/112 [==============================] - 5s 40ms/step - loss: 2.3570 - accuracy: 0.2399 - val_loss: 2.4961 - val_accuracy: 0.1956
# Epoch 17/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3497 - accuracy: 0.2430 - val_loss: 2.4899 - val_accuracy: 0.2002
# Epoch 18/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.3387 - accuracy: 0.2458 - val_loss: 2.5062 - val_accuracy: 0.1910
# Epoch 19/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3256 - accuracy: 0.2539 - val_loss: 2.4757 - val_accuracy: 0.1991
# Epoch 20/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3173 - accuracy: 0.2567 - val_loss: 2.4843 - val_accuracy: 0.1829
# Epoch 21/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3063 - accuracy: 0.2565 - val_loss: 2.4555 - val_accuracy: 0.2002
# Epoch 22/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.2946 - accuracy: 0.2520 - val_loss: 2.4562 - val_accuracy: 0.2002
# Epoch 23/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.2845 - accuracy: 0.2607 - val_loss: 2.4637 - val_accuracy: 0.2002
# Epoch 24/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.2725 - accuracy: 0.2629 - val_loss: 2.4386 - val_accuracy: 0.2095
# Epoch 25/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.2595 - accuracy: 0.2699 - val_loss: 2.4304 - val_accuracy: 0.2106
# 27/27 [==============================] - 1s 33ms/step - loss: 2.4301 - accuracy: 0.2095
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.7036 - accuracy: 0.0728 - val_loss: 2.6976 - val_accuracy: 0.0972
# Epoch 2/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6899 - accuracy: 0.1014 - val_loss: 2.6848 - val_accuracy: 0.0995
# Epoch 3/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6721 - accuracy: 0.1093 - val_loss: 2.6693 - val_accuracy: 0.1019
# Epoch 4/25
# 112/112 [==============================] - 4s 39ms/step - loss: 2.6459 - accuracy: 0.1253 - val_loss: 2.6514 - val_accuracy: 0.1065
# Epoch 5/25
# 112/112 [==============================] - 4s 39ms/step - loss: 2.6111 - accuracy: 0.1323 - val_loss: 2.6318 - val_accuracy: 0.0995
# Epoch 6/25
# 112/112 [==============================] - 5s 40ms/step - loss: 2.5719 - accuracy: 0.1421 - val_loss: 2.6057 - val_accuracy: 0.1250
# Epoch 7/25
# 112/112 [==============================] - 5s 40ms/step - loss: 2.5428 - accuracy: 0.1584 - val_loss: 2.5888 - val_accuracy: 0.1227
# Epoch 8/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.5192 - accuracy: 0.1669 - val_loss: 2.5962 - val_accuracy: 0.1296
# Epoch 9/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.4942 - accuracy: 0.1750 - val_loss: 2.5600 - val_accuracy: 0.1308
# Epoch 10/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.4763 - accuracy: 0.1972 - val_loss: 2.5428 - val_accuracy: 0.1574
# Epoch 11/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.4553 - accuracy: 0.1921 - val_loss: 2.5327 - val_accuracy: 0.1574
# Epoch 12/25
# 112/112 [==============================] - 5s 45ms/step - loss: 2.4322 - accuracy: 0.2014 - val_loss: 2.5097 - val_accuracy: 0.1748
# Epoch 13/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.4121 - accuracy: 0.2073 - val_loss: 2.4878 - val_accuracy: 0.1875
# Epoch 14/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.3787 - accuracy: 0.2205 - val_loss: 2.5389 - val_accuracy: 0.1690
# Epoch 15/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.3628 - accuracy: 0.2317 - val_loss: 2.4408 - val_accuracy: 0.2141
# Epoch 16/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.3310 - accuracy: 0.2419 - val_loss: 2.4569 - val_accuracy: 0.1921
# Epoch 17/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3025 - accuracy: 0.2500 - val_loss: 2.4016 - val_accuracy: 0.2141
# Epoch 18/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.2736 - accuracy: 0.2610 - val_loss: 2.3781 - val_accuracy: 0.2384
# Epoch 19/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.2297 - accuracy: 0.2725 - val_loss: 2.3539 - val_accuracy: 0.2257
# Epoch 20/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.2113 - accuracy: 0.2784 - val_loss: 2.3363 - val_accuracy: 0.2384
# Epoch 21/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.1810 - accuracy: 0.2815 - val_loss: 2.2884 - val_accuracy: 0.2535
# Epoch 22/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.1504 - accuracy: 0.2969 - val_loss: 2.2502 - val_accuracy: 0.2581
# Epoch 23/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.1141 - accuracy: 0.3067 - val_loss: 2.2357 - val_accuracy: 0.2662
# Epoch 24/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.0942 - accuracy: 0.3138 - val_loss: 2.3998 - val_accuracy: 0.2257
# Epoch 25/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.0619 - accuracy: 0.3295 - val_loss: 2.2725 - val_accuracy: 0.2685
# 27/27 [==============================] - 1s 35ms/step - loss: 2.2713 - accuracy: 0.2650
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/25
# 112/112 [==============================] - 5s 46ms/step - loss: 2.7204 - accuracy: 0.0862 - val_loss: 2.6926 - val_accuracy: 0.0903
# Epoch 2/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.6915 - accuracy: 0.0890 - val_loss: 2.6894 - val_accuracy: 0.0926
# Epoch 3/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6910 - accuracy: 0.0879 - val_loss: 2.6876 - val_accuracy: 0.0938
# Epoch 4/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6910 - accuracy: 0.0902 - val_loss: 2.6888 - val_accuracy: 0.0926
# Epoch 5/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6910 - accuracy: 0.0933 - val_loss: 2.6900 - val_accuracy: 0.0880
# Epoch 6/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6913 - accuracy: 0.0893 - val_loss: 2.6875 - val_accuracy: 0.0926
# Epoch 7/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6907 - accuracy: 0.0899 - val_loss: 2.6903 - val_accuracy: 0.0926
# Epoch 8/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6911 - accuracy: 0.0893 - val_loss: 2.6899 - val_accuracy: 0.0903
# Epoch 9/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6909 - accuracy: 0.0876 - val_loss: 2.6897 - val_accuracy: 0.0914
# Epoch 10/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6918 - accuracy: 0.0899 - val_loss: 2.6873 - val_accuracy: 0.0903
# Epoch 11/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6909 - accuracy: 0.0899 - val_loss: 2.6872 - val_accuracy: 0.0938
# Epoch 12/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6905 - accuracy: 0.0882 - val_loss: 2.6891 - val_accuracy: 0.0949
# Epoch 13/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6910 - accuracy: 0.0907 - val_loss: 2.6904 - val_accuracy: 0.0787
# Epoch 14/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6913 - accuracy: 0.0871 - val_loss: 2.6900 - val_accuracy: 0.0822
# Epoch 15/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6911 - accuracy: 0.0848 - val_loss: 2.6881 - val_accuracy: 0.0914
# Epoch 16/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6914 - accuracy: 0.0913 - val_loss: 2.6883 - val_accuracy: 0.0914
# Epoch 17/25
# 112/112 [==============================] - 5s 44ms/step - loss: 2.6908 - accuracy: 0.0907 - val_loss: 2.6896 - val_accuracy: 0.0914
# Epoch 18/25
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6909 - accuracy: 0.0899 - val_loss: 2.6883 - val_accuracy: 0.0926
# Epoch 19/25
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6916 - accuracy: 0.0868 - val_loss: 2.6880 - val_accuracy: 0.0938
# Epoch 20/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6911 - accuracy: 0.0904 - val_loss: 2.6888 - val_accuracy: 0.0903
# Epoch 21/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6910 - accuracy: 0.0854 - val_loss: 2.6869 - val_accuracy: 0.0938
# Epoch 22/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6911 - accuracy: 0.0902 - val_loss: 2.6879 - val_accuracy: 0.0926
# Epoch 23/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6914 - accuracy: 0.0910 - val_loss: 2.6886 - val_accuracy: 0.0914
# Epoch 24/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6914 - accuracy: 0.0885 - val_loss: 2.6872 - val_accuracy: 0.0903
# Epoch 25/25
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6915 - accuracy: 0.0913 - val_loss: 2.6882 - val_accuracy: 0.0914
# 27/27 [==============================] - 1s 32ms/step - loss: 2.6880 - accuracy: 0.0891

# %% [markdown]
# #5. Visualización del rendimiento

# %%
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(15,13))

plt.subplot(2, 1, 1)
plt.plot(range(EPOCHS), accs[0], label='Rendimiento train (accuracy), activation = linear')
plt.plot(range(EPOCHS), val_accs[0], label='Rendimiento validacion (accuracy), activation = linear')
plt.plot(range(EPOCHS), accs[1], label='Rendimiento train (accuracy), activation = tanh')
plt.plot(range(EPOCHS), val_accs[1], label='Rendimiento validacion (accuracy), activation = tanh')
plt.plot(range(EPOCHS), accs[2], label='Rendimiento train (accuracy), activation = relu')
plt.plot(range(EPOCHS), val_accs[2], label='Rendimiento validacion (accuracy), activation = relu')
plt.plot(range(EPOCHS), accs[3], label='Rendimiento train (accuracy), activation = sigmoid')
plt.plot(range(EPOCHS), val_accs[3], label='Rendimiento validacion (accuracy), activation = sigmoid')
plt.legend(loc='upper left')
plt.title('Training and Validation Accuracy')
plt.xlabel('# epoca')
plt.ylabel('Precision')
plt.tight_layout()

plt.subplot(2, 1, 2)
plt.plot(range(EPOCHS), losses[0], label='Pérdidas entrenamiento (Loss), activation = linear')
plt.plot(range(EPOCHS), val_losses[0], label='Pérdidas validacion (Loss), activation = linear')
plt.plot(range(EPOCHS), losses[1], label='Pérdidas entrenamiento (Loss), activation = tanh')
plt.plot(range(EPOCHS), val_losses[1], label='Pérdidas validacion (Loss), activation = tanh')
plt.plot(range(EPOCHS), losses[2], label='Pérdidas entrenamiento (Loss), activation = relu')
plt.plot(range(EPOCHS), val_losses[2], label='Pérdidas validacion (Loss), activation = relu')
plt.plot(range(EPOCHS), losses[3], label='Pérdidas entrenamiento (Loss), activation = sigmoid')
plt.plot(range(EPOCHS), val_losses[3], label='Pérdidas validacion (Loss), activation = sigmoid')
plt.legend(loc='upper left')
plt.title('Training and Validation Loss')
plt.xlabel('# epoca')
plt.ylabel('Perdida')
plt.tight_layout()


plt.show()

# %% [markdown]
# #Mostramos únicamente los resultados con activation = relu, ya que hemos considerado que es el mejor valor.

# %%
fig = plt.figure(figsize=(15,13))

# precision con activation = relu
plt.subplot(2, 1, 1)
plt.plot(range(EPOCHS), accs[2], label='Rendimiento train (accuracy)')
plt.plot(range(EPOCHS), val_accs[2], label='Rendimiento validacion (accuracy)')
plt.legend(loc='upper left')
plt.title('Training and Validation Accuracy, activation = relu')
plt.xlabel('# epoca')
plt.ylabel('Precision')
plt.tight_layout()

# perdidas con activation = relu
plt.subplot(2, 1, 2)
plt.plot(range(EPOCHS), losses[2], label='Pérdidas entrenamiento (Loss)')
plt.plot(range(EPOCHS), val_losses[2], label='Pérdidas validacion (Loss)')
plt.legend(loc='upper left')
plt.title('Training and Validation Loss, activation = relu')
plt.xlabel('# epoca')
plt.ylabel('Perdida')
plt.tight_layout()


plt.show()

# %% [markdown]
# #6.Guardar resultados

# %%
#guardar el modelo de red obtenido
#https://www.tensorflow.org/api_docs/python/tf/keras/Model
#https://www.tensorflow.org/tutorials/keras/save_and_load
os.chdir(dwld_dir)  
save_dir = dwld_dir + '/my_models'
subprocess.call(["mkdir","-p",save_dir])  # crear directorio para guardar modelo
model.save(
    save_dir,
    overwrite=True,
    include_optimizer=True,
)
# Out:
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/dwld_dir/my_models/assets
