# %% [markdown]
# # Notebook para la pregunta 4.1 sobre el reconocimiento de escenas con Redes Convolucionales Neuronales

# %% [markdown]
# # 1.Preparación del entorno de trabajo como en los notebooks anteriores

# %%
#%%capture
#%tensorflow_version 2.x
# !pip install tensorflow==2.3.0
import tensorflow as tf
import os, subprocess
# !python --version                     # mostrar version de python
print('Tensorflow ' + tf.__version__) # mostrar version tensorflow
# Out:
# Collecting tensorflow==2.3.0
#   Downloading tensorflow-2.3.0-cp37-cp37m-manylinux2010_x86_64.whl (320.4 MB)
#      |████████████████████████████████| 320.4 MB 46 kB/s
# Collecting numpy<1.19.0,>=1.16.0
#   Downloading numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 1.4 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.13.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.37.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.2.0)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.17.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.15.0)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Downloading tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
#      |████████████████████████████████| 459 kB 45.1 MB/s
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.12.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.3.0)
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.2)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.42.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.4.1)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 42.9 MB/s
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (2.7.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (57.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.8.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.10.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.1)
# Installing collected packages: numpy, tensorflow-estimator, h5py, gast, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed gast-0.3.3 h5py-2.10.0 numpy-1.18.5 tensorflow-2.3.0 tensorflow-estimator-2.3.0
# Python 3.7.12
# Tensorflow 2.3.0

# %% [markdown]
# # 2.Creación y almacenamiento de los datos

# %%
import os, subprocess

# Montar Google Drive y crear carpetas
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

work_dir = '/content/work_dir'                    # directorio de trabajo en local (mas rapido)
dwld_dir = '/content/gdrive/My Drive/dwld_dir'    # directorio de descarga en Google drive personal
subprocess.call(["mkdir","-p",work_dir])          # crear directorio para trabajo
subprocess.call(["mkdir","-p",dwld_dir+'/dataset/'])  # crear directorio para dataset

os.chdir(dwld_dir+'/dataset/')                        # posicionarse en el directorio
# Descargar dataset scenes15 si no esta disponible
if os.path.isfile('./dataset_scenes15.zip') == False: 
  # !wget http://www-vpu.eps.uam.es/~jcs/tsv/dataset_scenes15.zip 
  
# Copiar el dataset al directorio local (mayor velocidad de lectura que en Gdrive)
# !cp /content/gdrive/My\ Drive/dwld_dir/dataset/dataset_scenes15.zip /content/work_dir/

os.chdir(work_dir)                        # posicionarse en el directorio
if os.path.isdir('./scenes15') == False: 
  # !unzip -o -q dataset_scenes15.zip -d .

print('El dataset se encuentra descargado en el directorio {} \ny descomprimido en el directorio {} (usado para lectura de datos)'.format(dwld_dir, work_dir))
# Out:
# Mounted at /content/gdrive
# El dataset se encuentra descargado en el directorio /content/gdrive/My Drive/dwld_dir
# y descomprimido en el directorio /content/work_dir (usado para lectura de datos)

# %% [markdown]
# # 3.Seleccionamos Hardware como en ejemplos previos

# %%
import tensorflow as tf
import time

print("Num CPUs disponibles: ", len(tf.config.experimental.list_physical_devices('CPU')))
print("Num GPUs disponibles: ", len(tf.config.experimental.list_physical_devices('GPU')))

time1 = time.time() # medida de tiempo

# ejecutar en CPU
with tf.device('/CPU:0'):
  random_image_cpu = tf.random.normal((100, 100, 100, 3))
  net_cpu = tf.keras.layers.Conv2D(128, 7)(random_image_cpu)

time2 = time.time() # medida de tiempo

# ejecutar en GPU
with tf.device('/device:GPU:0'):
  random_image_cpu = tf.random.normal((100, 100, 100, 3))
  net_cpu = tf.keras.layers.Conv2D(128, 7)(random_image_cpu)

time3 = time.time() # medida de tiempo
print('Tiempo ejecución CPU {} secs y GPU {} secs' .format(time2-time1, time3-time2))
print('Ejecute varias veces este bloque de código pues la primera vez no observará diferencias debido a que se deben inicializar los registros para la CPU y GPU')
# Out:
# Num CPUs disponibles:  1
# Num GPUs disponibles:  1
# Tiempo ejecución CPU 1.7435216903686523 secs y GPU 2.976773500442505 secs
# Ejecute varias veces este bloque de código pues la primera vez no observará diferencias debido a que se deben inicializar los registros para la CPU y GPU

# %% [markdown]
# # 4.Crear iterador para los datos del dataset, definición del modelo, optimización de parámetros, entrenamiento y clasificación

# %%
import tensorflow as tf
import pathlib
import numpy as np
import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
import tensorflow.keras.optimizers as optimizers
import matplotlib.pyplot as plt

batch_sizes = [8, 16, 32, 64]
accs = []
val_accs = []
losses = []
val_losses = []

for batch_size in batch_sizes:

  dataset_dir = pathlib.Path(work_dir + '/scenes15/')

  # Obtener etiquetas de clase y numero de clases
  CLASS_NAMES = np.array([item.name for item in dataset_dir.glob('*')]) #clases son subdirectorios de '/train/'
  NUM_CLASSES = len(CLASS_NAMES) # numero total de clases
 
  # Crear ImageDataGenerator convirtiendo de uint8 a float32 en el rango [0,1].
  img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20)

  # Obtenemos un iterador sobre los datos de entrenamiento del dataset
  # aplicando el ImageDataGenerator creado anteriormente
  BATCH_SIZE = batch_size # numero de elementos procesados conjuntamente en cada iteracion
  IMG_HEIGHT = 32
  IMG_WIDTH = 32
  IMG_CHANNELS = 3

  train_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',                                                     
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE, 
                                            subset="training",                                         
                                            shuffle=True,
                                            seed=0)

  test_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',                                                     
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="validation",
                                            shuffle=True,
                                            seed=0)
  
  # definir modelo de red
  model = models.Sequential()

  # incluir capa convolucional C1
  model.add(layers.Conv2D(filters=6, 
                          kernel_size=(3, 3), 
                          strides = (1,1),
                          padding = 'valid',
                          activation='relu', 
                          input_shape=(IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)))

  # incluir average pooling S2
  model.add(layers.AveragePooling2D())

  # incluir capa convolucional C3
  model.add(layers.Conv2D(filters=16, 
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid', 
                          activation='relu'))

  # incluir average pooling S4
  model.add(layers.AveragePooling2D())

  # convertir el volumen de datos en vector fila para conectarlo con capa FC
  model.add(layers.Flatten())

  # incluir fully convolutional F5
  model.add(layers.Dense(units=120, activation='relu'))

  # incluir fully convolutional F6
  model.add(layers.Dense(units=84, activation='relu'))

  # incluir salida OUTPUT
  model.add(layers.Dense(units=NUM_CLASSES, activation = 'softmax'))

  LEARNING_RATE = 0.01 # factor de aprendizaje
  model.compile(optimizer=optimizers.SGD(lr=LEARNING_RATE),            
            loss='categorical_crossentropy',            
            metrics=['accuracy'])
  
  EPOCHS = 50 # numero de epocas para entrenamiento

  #si tiene problemas al ejecutar con la GPU, 
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    history = model.fit_generator(
        generator=train_data_gen,          
        steps_per_epoch=train_data_gen.n // BATCH_SIZE,      
        validation_data=test_data_gen,
        validation_steps=test_data_gen.n // BATCH_SIZE,
        epochs=EPOCHS,
        verbose=1     
    )  

  #si tiene problemas al ejecutar con la GPU, 
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    test_loss, test_acc = model.evaluate_generator(generator=test_data_gen, 
                                                  steps = test_data_gen.n // BATCH_SIZE, 
                                                  verbose=1)
  accs.append(history.history['accuracy']) 
  val_accs.append(history.history['val_accuracy'])
  losses.append(history.history['loss'])
  val_losses.append(history.history['val_loss'])
# Out:
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# WARNING:tensorflow:From <ipython-input-3-7b5d3f141828>:107: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 449/449 [==============================] - 6s 13ms/step - loss: 2.6941 - accuracy: 0.0924 - val_loss: 2.6776 - val_accuracy: 0.1126
# Epoch 2/50
# 449/449 [==============================] - 6s 12ms/step - loss: 2.6470 - accuracy: 0.1219 - val_loss: 2.6419 - val_accuracy: 0.1261
# Epoch 3/50
# 449/449 [==============================] - 6s 12ms/step - loss: 2.5712 - accuracy: 0.1448 - val_loss: 2.5914 - val_accuracy: 0.1396
# Epoch 4/50
# 449/449 [==============================] - 6s 13ms/step - loss: 2.4972 - accuracy: 0.1765 - val_loss: 2.5234 - val_accuracy: 0.1993
# Epoch 5/50
# 449/449 [==============================] - 6s 12ms/step - loss: 2.4226 - accuracy: 0.2096 - val_loss: 2.4849 - val_accuracy: 0.1892
# Epoch 6/50
# 449/449 [==============================] - 6s 13ms/step - loss: 2.3655 - accuracy: 0.2350 - val_loss: 2.4429 - val_accuracy: 0.2061
# Epoch 7/50
# 449/449 [==============================] - 6s 12ms/step - loss: 2.3038 - accuracy: 0.2447 - val_loss: 2.4125 - val_accuracy: 0.2083
# Epoch 8/50
# 449/449 [==============================] - 6s 13ms/step - loss: 2.2421 - accuracy: 0.2645 - val_loss: 2.3945 - val_accuracy: 0.2410
# Epoch 9/50
# 449/449 [==============================] - 6s 12ms/step - loss: 2.1801 - accuracy: 0.2890 - val_loss: 2.3871 - val_accuracy: 0.2523
# Epoch 10/50
# 449/449 [==============================] - 6s 12ms/step - loss: 2.1009 - accuracy: 0.3107 - val_loss: 2.2144 - val_accuracy: 0.2736
# Epoch 11/50
# 449/449 [==============================] - 6s 12ms/step - loss: 2.0193 - accuracy: 0.3366 - val_loss: 2.2169 - val_accuracy: 0.2860
# Epoch 12/50
# 449/449 [==============================] - 6s 13ms/step - loss: 1.9635 - accuracy: 0.3502 - val_loss: 2.2483 - val_accuracy: 0.2590
# Epoch 13/50
# 449/449 [==============================] - 6s 12ms/step - loss: 1.8972 - accuracy: 0.3686 - val_loss: 2.0850 - val_accuracy: 0.3119
# Epoch 14/50
# 449/449 [==============================] - 6s 13ms/step - loss: 1.8436 - accuracy: 0.3959 - val_loss: 2.1009 - val_accuracy: 0.3086
# Epoch 15/50
# 449/449 [==============================] - 6s 12ms/step - loss: 1.7592 - accuracy: 0.4042 - val_loss: 2.1294 - val_accuracy: 0.2984
# Epoch 16/50
# 449/449 [==============================] - 6s 12ms/step - loss: 1.7190 - accuracy: 0.4234 - val_loss: 2.0972 - val_accuracy: 0.3176
# Epoch 17/50
# 449/449 [==============================] - 6s 13ms/step - loss: 1.6687 - accuracy: 0.4446 - val_loss: 2.1249 - val_accuracy: 0.3176
# Epoch 18/50
# 449/449 [==============================] - 6s 12ms/step - loss: 1.6095 - accuracy: 0.4610 - val_loss: 2.1451 - val_accuracy: 0.3063
# Epoch 19/50
# 449/449 [==============================] - 6s 12ms/step - loss: 1.5465 - accuracy: 0.4794 - val_loss: 2.1359 - val_accuracy: 0.3221
# Epoch 20/50
# 449/449 [==============================] - 6s 13ms/step - loss: 1.4796 - accuracy: 0.5131 - val_loss: 2.0438 - val_accuracy: 0.3514
# Epoch 21/50
# 449/449 [==============================] - 6s 13ms/step - loss: 1.4288 - accuracy: 0.5220 - val_loss: 2.1510 - val_accuracy: 0.3266
# Epoch 22/50
# 449/449 [==============================] - 6s 13ms/step - loss: 1.3639 - accuracy: 0.5493 - val_loss: 2.2168 - val_accuracy: 0.3176
# Epoch 23/50
# 449/449 [==============================] - 6s 13ms/step - loss: 1.3051 - accuracy: 0.5632 - val_loss: 2.2872 - val_accuracy: 0.3232
# Epoch 24/50
# 449/449 [==============================] - 6s 12ms/step - loss: 1.2414 - accuracy: 0.5732 - val_loss: 2.3479 - val_accuracy: 0.3176
# Epoch 25/50
# 449/449 [==============================] - 6s 12ms/step - loss: 1.1561 - accuracy: 0.6161 - val_loss: 2.3267 - val_accuracy: 0.3412
# Epoch 26/50
# 449/449 [==============================] - 6s 12ms/step - loss: 1.1019 - accuracy: 0.6347 - val_loss: 2.4160 - val_accuracy: 0.3277
# Epoch 27/50
# 449/449 [==============================] - 6s 12ms/step - loss: 1.0278 - accuracy: 0.6512 - val_loss: 2.5298 - val_accuracy: 0.3311
# Epoch 28/50
# 449/449 [==============================] - 6s 12ms/step - loss: 0.9652 - accuracy: 0.6868 - val_loss: 2.4518 - val_accuracy: 0.3480
# Epoch 29/50
# 449/449 [==============================] - 6s 12ms/step - loss: 0.8780 - accuracy: 0.7021 - val_loss: 2.5874 - val_accuracy: 0.3491
# Epoch 30/50
# 449/449 [==============================] - 6s 12ms/step - loss: 0.8148 - accuracy: 0.7210 - val_loss: 2.8377 - val_accuracy: 0.3052
# Epoch 31/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.7641 - accuracy: 0.7464 - val_loss: 2.8529 - val_accuracy: 0.3356
# Epoch 32/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.6887 - accuracy: 0.7595 - val_loss: 3.0462 - val_accuracy: 0.3108
# Epoch 33/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.6369 - accuracy: 0.7879 - val_loss: 3.0743 - val_accuracy: 0.3378
# Epoch 34/50
# 449/449 [==============================] - 6s 12ms/step - loss: 0.5666 - accuracy: 0.8115 - val_loss: 3.1207 - val_accuracy: 0.3288
# Epoch 35/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.5313 - accuracy: 0.8252 - val_loss: 3.4460 - val_accuracy: 0.3288
# Epoch 36/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.4743 - accuracy: 0.8413 - val_loss: 3.3640 - val_accuracy: 0.3300
# Epoch 37/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.4510 - accuracy: 0.8469 - val_loss: 3.8163 - val_accuracy: 0.3198
# Epoch 38/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.3860 - accuracy: 0.8694 - val_loss: 3.8179 - val_accuracy: 0.3491
# Epoch 39/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.3625 - accuracy: 0.8806 - val_loss: 4.0093 - val_accuracy: 0.3164
# Epoch 40/50
# 449/449 [==============================] - 6s 12ms/step - loss: 0.3078 - accuracy: 0.8911 - val_loss: 3.8086 - val_accuracy: 0.3322
# Epoch 41/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.2700 - accuracy: 0.9198 - val_loss: 4.2416 - val_accuracy: 0.3311
# Epoch 42/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.2959 - accuracy: 0.9048 - val_loss: 4.3010 - val_accuracy: 0.3243
# Epoch 43/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.2341 - accuracy: 0.9271 - val_loss: 4.3368 - val_accuracy: 0.3333
# Epoch 44/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.2455 - accuracy: 0.9220 - val_loss: 4.3907 - val_accuracy: 0.3367
# Epoch 45/50
# 449/449 [==============================] - 6s 12ms/step - loss: 0.2030 - accuracy: 0.9396 - val_loss: 4.9652 - val_accuracy: 0.3221
# Epoch 46/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.1975 - accuracy: 0.9360 - val_loss: 4.8257 - val_accuracy: 0.3198
# Epoch 47/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.1698 - accuracy: 0.9468 - val_loss: 4.6137 - val_accuracy: 0.3727
# Epoch 48/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.2095 - accuracy: 0.9357 - val_loss: 4.8992 - val_accuracy: 0.3423
# Epoch 49/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.1088 - accuracy: 0.9713 - val_loss: 4.9902 - val_accuracy: 0.3345
# Epoch 50/50
# 449/449 [==============================] - 6s 13ms/step - loss: 0.0923 - accuracy: 0.9755 - val_loss: 5.1577 - val_accuracy: 0.3502
# WARNING:tensorflow:From <ipython-input-3-7b5d3f141828>:117: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# 111/111 [==============================] - 1s 10ms/step - loss: 5.1445 - accuracy: 0.3514
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/50
# 224/224 [==============================] - 5s 23ms/step - loss: 2.6936 - accuracy: 0.0828 - val_loss: 2.6763 - val_accuracy: 0.0864
# Epoch 2/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.6460 - accuracy: 0.1135 - val_loss: 2.6516 - val_accuracy: 0.1057
# Epoch 3/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.5891 - accuracy: 0.1393 - val_loss: 2.6087 - val_accuracy: 0.1216
# Epoch 4/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.5376 - accuracy: 0.1655 - val_loss: 2.5783 - val_accuracy: 0.1227
# Epoch 5/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.4941 - accuracy: 0.1874 - val_loss: 2.5535 - val_accuracy: 0.1489
# Epoch 6/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.4518 - accuracy: 0.1930 - val_loss: 2.5121 - val_accuracy: 0.1830
# Epoch 7/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.4153 - accuracy: 0.2061 - val_loss: 2.4881 - val_accuracy: 0.2011
# Epoch 8/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.3734 - accuracy: 0.2318 - val_loss: 2.4497 - val_accuracy: 0.2091
# Epoch 9/50
# 224/224 [==============================] - 5s 23ms/step - loss: 2.3264 - accuracy: 0.2430 - val_loss: 2.4769 - val_accuracy: 0.2102
# Epoch 10/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.2818 - accuracy: 0.2620 - val_loss: 2.3797 - val_accuracy: 0.2318
# Epoch 11/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.2339 - accuracy: 0.2777 - val_loss: 2.3256 - val_accuracy: 0.2568
# Epoch 12/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.1742 - accuracy: 0.2947 - val_loss: 2.3580 - val_accuracy: 0.2477
# Epoch 13/50
# 224/224 [==============================] - 5s 23ms/step - loss: 2.1143 - accuracy: 0.3143 - val_loss: 2.2038 - val_accuracy: 0.2864
# Epoch 14/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.0569 - accuracy: 0.3188 - val_loss: 2.4182 - val_accuracy: 0.2148
# Epoch 15/50
# 224/224 [==============================] - 5s 22ms/step - loss: 2.0059 - accuracy: 0.3406 - val_loss: 2.2481 - val_accuracy: 0.2670
# Epoch 16/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.9441 - accuracy: 0.3493 - val_loss: 2.1139 - val_accuracy: 0.2955
# Epoch 17/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.9021 - accuracy: 0.3683 - val_loss: 2.1102 - val_accuracy: 0.2875
# Epoch 18/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.8501 - accuracy: 0.3943 - val_loss: 2.0551 - val_accuracy: 0.3159
# Epoch 19/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.8100 - accuracy: 0.4007 - val_loss: 2.0768 - val_accuracy: 0.2898
# Epoch 20/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.7753 - accuracy: 0.4049 - val_loss: 2.0588 - val_accuracy: 0.3216
# Epoch 21/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.7243 - accuracy: 0.4318 - val_loss: 1.9640 - val_accuracy: 0.3568
# Epoch 22/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.6807 - accuracy: 0.4404 - val_loss: 2.1376 - val_accuracy: 0.2955
# Epoch 23/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.6549 - accuracy: 0.4480 - val_loss: 2.1715 - val_accuracy: 0.2955
# Epoch 24/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.6153 - accuracy: 0.4642 - val_loss: 2.0138 - val_accuracy: 0.3205
# Epoch 25/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.5775 - accuracy: 0.4740 - val_loss: 1.9911 - val_accuracy: 0.3375
# Epoch 26/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.5396 - accuracy: 0.4829 - val_loss: 1.8924 - val_accuracy: 0.3648
# Epoch 27/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.5105 - accuracy: 0.4930 - val_loss: 1.9645 - val_accuracy: 0.3750
# Epoch 28/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.4674 - accuracy: 0.5020 - val_loss: 2.0344 - val_accuracy: 0.3511
# Epoch 29/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.4472 - accuracy: 0.5131 - val_loss: 1.8980 - val_accuracy: 0.3727
# Epoch 30/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.3944 - accuracy: 0.5296 - val_loss: 2.0734 - val_accuracy: 0.3659
# Epoch 31/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.3711 - accuracy: 0.5459 - val_loss: 2.0053 - val_accuracy: 0.3705
# Epoch 32/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.3344 - accuracy: 0.5515 - val_loss: 1.9803 - val_accuracy: 0.3727
# Epoch 33/50
# 224/224 [==============================] - 5s 23ms/step - loss: 1.2978 - accuracy: 0.5598 - val_loss: 2.0200 - val_accuracy: 0.3614
# Epoch 34/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.2703 - accuracy: 0.5677 - val_loss: 1.9356 - val_accuracy: 0.3886
# Epoch 35/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.2207 - accuracy: 0.5831 - val_loss: 2.0503 - val_accuracy: 0.3659
# Epoch 36/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.1825 - accuracy: 0.6015 - val_loss: 1.9682 - val_accuracy: 0.3852
# Epoch 37/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.1465 - accuracy: 0.6082 - val_loss: 2.1397 - val_accuracy: 0.3523
# Epoch 38/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.1156 - accuracy: 0.6202 - val_loss: 2.0665 - val_accuracy: 0.3682
# Epoch 39/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.0873 - accuracy: 0.6292 - val_loss: 2.0250 - val_accuracy: 0.3898
# Epoch 40/50
# 224/224 [==============================] - 5s 22ms/step - loss: 1.0338 - accuracy: 0.6457 - val_loss: 2.1393 - val_accuracy: 0.3920
# Epoch 41/50
# 224/224 [==============================] - 5s 23ms/step - loss: 0.9917 - accuracy: 0.6672 - val_loss: 2.1110 - val_accuracy: 0.3818
# Epoch 42/50
# 224/224 [==============================] - 5s 23ms/step - loss: 0.9530 - accuracy: 0.6776 - val_loss: 2.1607 - val_accuracy: 0.3977
# Epoch 43/50
# 224/224 [==============================] - 5s 23ms/step - loss: 0.9274 - accuracy: 0.6876 - val_loss: 2.3412 - val_accuracy: 0.3580
# Epoch 44/50
# 224/224 [==============================] - 5s 23ms/step - loss: 0.8928 - accuracy: 0.6991 - val_loss: 2.1918 - val_accuracy: 0.4239
# Epoch 45/50
# 224/224 [==============================] - 5s 23ms/step - loss: 0.8424 - accuracy: 0.7198 - val_loss: 2.1838 - val_accuracy: 0.3920
# Epoch 46/50
# 224/224 [==============================] - 5s 23ms/step - loss: 0.7950 - accuracy: 0.7352 - val_loss: 2.2464 - val_accuracy: 0.4023
# Epoch 47/50
# 224/224 [==============================] - 5s 23ms/step - loss: 0.7656 - accuracy: 0.7475 - val_loss: 2.2649 - val_accuracy: 0.3955
# Epoch 48/50
# 224/224 [==============================] - 5s 23ms/step - loss: 0.7381 - accuracy: 0.7525 - val_loss: 2.3512 - val_accuracy: 0.3841
# Epoch 49/50
# 224/224 [==============================] - 5s 22ms/step - loss: 0.6825 - accuracy: 0.7718 - val_loss: 2.5782 - val_accuracy: 0.3477
# Epoch 50/50
# 224/224 [==============================] - 5s 23ms/step - loss: 0.6549 - accuracy: 0.7808 - val_loss: 2.4600 - val_accuracy: 0.3705
# 55/55 [==============================] - 1s 18ms/step - loss: 2.4611 - accuracy: 0.3705
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.7071 - accuracy: 0.0688 - val_loss: 2.7038 - val_accuracy: 0.0775
# Epoch 2/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.7012 - accuracy: 0.1008 - val_loss: 2.6997 - val_accuracy: 0.0880
# Epoch 3/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6972 - accuracy: 0.1084 - val_loss: 2.6957 - val_accuracy: 0.1019
# Epoch 4/50
# 112/112 [==============================] - 5s 40ms/step - loss: 2.6928 - accuracy: 0.1194 - val_loss: 2.6920 - val_accuracy: 0.1181
# Epoch 5/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6888 - accuracy: 0.1236 - val_loss: 2.6884 - val_accuracy: 0.1227
# Epoch 6/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6838 - accuracy: 0.1236 - val_loss: 2.6829 - val_accuracy: 0.1262
# Epoch 7/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6777 - accuracy: 0.1230 - val_loss: 2.6779 - val_accuracy: 0.1204
# Epoch 8/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6697 - accuracy: 0.1275 - val_loss: 2.6696 - val_accuracy: 0.1215
# Epoch 9/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6580 - accuracy: 0.1312 - val_loss: 2.6583 - val_accuracy: 0.1169
# Epoch 10/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6401 - accuracy: 0.1458 - val_loss: 2.6404 - val_accuracy: 0.1065
# Epoch 11/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6099 - accuracy: 0.1680 - val_loss: 2.6176 - val_accuracy: 0.1424
# Epoch 12/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.5694 - accuracy: 0.1677 - val_loss: 2.5898 - val_accuracy: 0.1470
# Epoch 13/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.5271 - accuracy: 0.1792 - val_loss: 2.5562 - val_accuracy: 0.1528
# Epoch 14/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.4787 - accuracy: 0.1899 - val_loss: 2.5383 - val_accuracy: 0.1655
# Epoch 15/50
# 112/112 [==============================] - 5s 40ms/step - loss: 2.4374 - accuracy: 0.2093 - val_loss: 2.4963 - val_accuracy: 0.1782
# Epoch 16/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.4095 - accuracy: 0.2157 - val_loss: 2.4468 - val_accuracy: 0.2025
# Epoch 17/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.3594 - accuracy: 0.2337 - val_loss: 2.4055 - val_accuracy: 0.2245
# Epoch 18/50
# 112/112 [==============================] - 4s 40ms/step - loss: 2.3118 - accuracy: 0.2433 - val_loss: 2.4474 - val_accuracy: 0.2384
# Epoch 19/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.2749 - accuracy: 0.2551 - val_loss: 2.3373 - val_accuracy: 0.2512
# Epoch 20/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.2401 - accuracy: 0.2705 - val_loss: 2.2950 - val_accuracy: 0.2836
# Epoch 21/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.1697 - accuracy: 0.2919 - val_loss: 2.2301 - val_accuracy: 0.2766
# Epoch 22/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.1511 - accuracy: 0.2857 - val_loss: 2.2509 - val_accuracy: 0.2558
# Epoch 23/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.0762 - accuracy: 0.3132 - val_loss: 2.2454 - val_accuracy: 0.2708
# Epoch 24/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.0614 - accuracy: 0.3202 - val_loss: 2.1368 - val_accuracy: 0.3229
# Epoch 25/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.0264 - accuracy: 0.3287 - val_loss: 2.1114 - val_accuracy: 0.3287
# Epoch 26/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.0022 - accuracy: 0.3317 - val_loss: 2.0721 - val_accuracy: 0.3229
# Epoch 27/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.9502 - accuracy: 0.3469 - val_loss: 2.0194 - val_accuracy: 0.3565
# Epoch 28/50
# 112/112 [==============================] - 5s 42ms/step - loss: 1.9216 - accuracy: 0.3567 - val_loss: 2.0262 - val_accuracy: 0.3368
# Epoch 29/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.9098 - accuracy: 0.3649 - val_loss: 1.9974 - val_accuracy: 0.3565
# Epoch 30/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.8925 - accuracy: 0.3640 - val_loss: 2.0303 - val_accuracy: 0.3252
# Epoch 31/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.8751 - accuracy: 0.3685 - val_loss: 1.9921 - val_accuracy: 0.3681
# Epoch 32/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.8575 - accuracy: 0.3857 - val_loss: 2.0000 - val_accuracy: 0.3345
# Epoch 33/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.8271 - accuracy: 0.3933 - val_loss: 1.9802 - val_accuracy: 0.3449
# Epoch 34/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.8168 - accuracy: 0.3882 - val_loss: 1.9629 - val_accuracy: 0.3356
# Epoch 35/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.8007 - accuracy: 0.4014 - val_loss: 1.9791 - val_accuracy: 0.3634
# Epoch 36/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.7838 - accuracy: 0.4101 - val_loss: 1.9757 - val_accuracy: 0.3449
# Epoch 37/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.7674 - accuracy: 0.4140 - val_loss: 1.9691 - val_accuracy: 0.3773
# Epoch 38/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.7407 - accuracy: 0.4194 - val_loss: 1.9736 - val_accuracy: 0.3519
# Epoch 39/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.7139 - accuracy: 0.4264 - val_loss: 1.9928 - val_accuracy: 0.3519
# Epoch 40/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.7026 - accuracy: 0.4303 - val_loss: 1.9289 - val_accuracy: 0.3542
# Epoch 41/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.6919 - accuracy: 0.4346 - val_loss: 1.8932 - val_accuracy: 0.3623
# Epoch 42/50
# 112/112 [==============================] - 5s 40ms/step - loss: 1.6709 - accuracy: 0.4399 - val_loss: 1.9235 - val_accuracy: 0.3715
# Epoch 43/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.6606 - accuracy: 0.4556 - val_loss: 1.9013 - val_accuracy: 0.3704
# Epoch 44/50
# 112/112 [==============================] - 5s 40ms/step - loss: 1.6580 - accuracy: 0.4508 - val_loss: 1.9070 - val_accuracy: 0.3681
# Epoch 45/50
# 112/112 [==============================] - 5s 40ms/step - loss: 1.6132 - accuracy: 0.4632 - val_loss: 1.9148 - val_accuracy: 0.3657
# Epoch 46/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.5981 - accuracy: 0.4638 - val_loss: 1.8685 - val_accuracy: 0.3750
# Epoch 47/50
# 112/112 [==============================] - 5s 40ms/step - loss: 1.6104 - accuracy: 0.4688 - val_loss: 1.9295 - val_accuracy: 0.3692
# Epoch 48/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.5669 - accuracy: 0.4890 - val_loss: 1.9091 - val_accuracy: 0.3669
# Epoch 49/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.5466 - accuracy: 0.4919 - val_loss: 1.8176 - val_accuracy: 0.3981
# Epoch 50/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.5239 - accuracy: 0.4992 - val_loss: 1.8629 - val_accuracy: 0.3924
# 27/27 [==============================] - 1s 32ms/step - loss: 1.8579 - accuracy: 0.3935
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/50
# 56/56 [==============================] - 5s 83ms/step - loss: 2.7121 - accuracy: 0.0731 - val_loss: 2.7080 - val_accuracy: 0.0889
# Epoch 2/50
# 56/56 [==============================] - 4s 79ms/step - loss: 2.6991 - accuracy: 0.0785 - val_loss: 2.7005 - val_accuracy: 0.0938
# Epoch 3/50
# 56/56 [==============================] - 4s 79ms/step - loss: 2.6924 - accuracy: 0.0967 - val_loss: 2.6965 - val_accuracy: 0.1010
# Epoch 4/50
# 56/56 [==============================] - 4s 78ms/step - loss: 2.6868 - accuracy: 0.0981 - val_loss: 2.6905 - val_accuracy: 0.0950
# Epoch 5/50
# 56/56 [==============================] - 4s 77ms/step - loss: 2.6820 - accuracy: 0.0944 - val_loss: 2.6856 - val_accuracy: 0.0913
# Epoch 6/50
# 56/56 [==============================] - 4s 79ms/step - loss: 2.6756 - accuracy: 0.0935 - val_loss: 2.6824 - val_accuracy: 0.0974
# Epoch 7/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.6685 - accuracy: 0.0986 - val_loss: 2.6736 - val_accuracy: 0.0901
# Epoch 8/50
# 56/56 [==============================] - 4s 78ms/step - loss: 2.6585 - accuracy: 0.1015 - val_loss: 2.6634 - val_accuracy: 0.1022
# Epoch 9/50
# 56/56 [==============================] - 4s 78ms/step - loss: 2.6459 - accuracy: 0.1094 - val_loss: 2.6594 - val_accuracy: 0.1070
# Epoch 10/50
# 56/56 [==============================] - 4s 77ms/step - loss: 2.6278 - accuracy: 0.1213 - val_loss: 2.6410 - val_accuracy: 0.1430
# Epoch 11/50
# 56/56 [==============================] - 4s 79ms/step - loss: 2.6050 - accuracy: 0.1533 - val_loss: 2.6273 - val_accuracy: 0.1406
# Epoch 12/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.5781 - accuracy: 0.1567 - val_loss: 2.6066 - val_accuracy: 0.1298
# Epoch 13/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.5498 - accuracy: 0.1704 - val_loss: 2.5836 - val_accuracy: 0.1430
# Epoch 14/50
# 56/56 [==============================] - 5s 81ms/step - loss: 2.5189 - accuracy: 0.1803 - val_loss: 2.5839 - val_accuracy: 0.1370
# Epoch 15/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.4928 - accuracy: 0.1893 - val_loss: 2.5550 - val_accuracy: 0.1394
# Epoch 16/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.4868 - accuracy: 0.1842 - val_loss: 2.5335 - val_accuracy: 0.1695
# Epoch 17/50
# 56/56 [==============================] - 4s 77ms/step - loss: 2.4544 - accuracy: 0.1984 - val_loss: 2.5809 - val_accuracy: 0.1430
# Epoch 18/50
# 56/56 [==============================] - 4s 79ms/step - loss: 2.4293 - accuracy: 0.2112 - val_loss: 2.5135 - val_accuracy: 0.1815
# Epoch 19/50
# 56/56 [==============================] - 4s 78ms/step - loss: 2.4096 - accuracy: 0.2106 - val_loss: 2.5209 - val_accuracy: 0.1731
# Epoch 20/50
# 56/56 [==============================] - 4s 78ms/step - loss: 2.3970 - accuracy: 0.2174 - val_loss: 2.4684 - val_accuracy: 0.2019
# Epoch 21/50
# 56/56 [==============================] - 4s 78ms/step - loss: 2.3877 - accuracy: 0.2304 - val_loss: 2.4683 - val_accuracy: 0.1899
# Epoch 22/50
# 56/56 [==============================] - 4s 79ms/step - loss: 2.3624 - accuracy: 0.2296 - val_loss: 2.4884 - val_accuracy: 0.1839
# Epoch 23/50
# 56/56 [==============================] - 4s 79ms/step - loss: 2.3509 - accuracy: 0.2395 - val_loss: 2.4927 - val_accuracy: 0.1887
# Epoch 24/50
# 56/56 [==============================] - 5s 81ms/step - loss: 2.3365 - accuracy: 0.2423 - val_loss: 2.4976 - val_accuracy: 0.1707
# Epoch 25/50
# 56/56 [==============================] - 5s 81ms/step - loss: 2.3179 - accuracy: 0.2548 - val_loss: 2.4656 - val_accuracy: 0.1887
# Epoch 26/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.3110 - accuracy: 0.2466 - val_loss: 2.5099 - val_accuracy: 0.1767
# Epoch 27/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.2867 - accuracy: 0.2588 - val_loss: 2.3995 - val_accuracy: 0.2200
# Epoch 28/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.2639 - accuracy: 0.2630 - val_loss: 2.4183 - val_accuracy: 0.1935
# Epoch 29/50
# 56/56 [==============================] - 4s 79ms/step - loss: 2.2473 - accuracy: 0.2625 - val_loss: 2.3726 - val_accuracy: 0.2236
# Epoch 30/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.2370 - accuracy: 0.2732 - val_loss: 2.3453 - val_accuracy: 0.2440
# Epoch 31/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.2451 - accuracy: 0.2749 - val_loss: 2.3367 - val_accuracy: 0.2320
# Epoch 32/50
# 56/56 [==============================] - 4s 79ms/step - loss: 2.2156 - accuracy: 0.2721 - val_loss: 2.3404 - val_accuracy: 0.2296
# Epoch 33/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.2009 - accuracy: 0.2846 - val_loss: 2.3715 - val_accuracy: 0.2272
# Epoch 34/50
# 56/56 [==============================] - 5s 81ms/step - loss: 2.1846 - accuracy: 0.2914 - val_loss: 2.3126 - val_accuracy: 0.2608
# Epoch 35/50
# 56/56 [==============================] - 5s 81ms/step - loss: 2.1942 - accuracy: 0.2937 - val_loss: 2.2690 - val_accuracy: 0.2560
# Epoch 36/50
# 56/56 [==============================] - 5s 81ms/step - loss: 2.1370 - accuracy: 0.3073 - val_loss: 2.2842 - val_accuracy: 0.2416
# Epoch 37/50
# 56/56 [==============================] - 4s 80ms/step - loss: 2.1235 - accuracy: 0.2996 - val_loss: 2.2604 - val_accuracy: 0.2656
# Epoch 38/50
# 56/56 [==============================] - 5s 81ms/step - loss: 2.1136 - accuracy: 0.3107 - val_loss: 2.3010 - val_accuracy: 0.2560
# Epoch 39/50
# 56/56 [==============================] - 5s 81ms/step - loss: 2.0993 - accuracy: 0.3084 - val_loss: 2.2132 - val_accuracy: 0.2692
# Epoch 40/50
# 56/56 [==============================] - 5s 82ms/step - loss: 2.0851 - accuracy: 0.3166 - val_loss: 2.2189 - val_accuracy: 0.2825
# Epoch 41/50
# 56/56 [==============================] - 5s 81ms/step - loss: 2.0501 - accuracy: 0.3203 - val_loss: 2.2417 - val_accuracy: 0.2752
# Epoch 42/50
# 56/56 [==============================] - 5s 80ms/step - loss: 2.0476 - accuracy: 0.3299 - val_loss: 2.2149 - val_accuracy: 0.2740
# Epoch 43/50
# 56/56 [==============================] - 5s 82ms/step - loss: 2.0364 - accuracy: 0.3316 - val_loss: 2.2088 - val_accuracy: 0.2776
# Epoch 44/50
# 56/56 [==============================] - 5s 81ms/step - loss: 2.0246 - accuracy: 0.3410 - val_loss: 2.1500 - val_accuracy: 0.2921
# Epoch 45/50
# 56/56 [==============================] - 5s 81ms/step - loss: 1.9790 - accuracy: 0.3583 - val_loss: 2.1636 - val_accuracy: 0.2969
# Epoch 46/50
# 56/56 [==============================] - 5s 81ms/step - loss: 1.9779 - accuracy: 0.3543 - val_loss: 2.1184 - val_accuracy: 0.2969
# Epoch 47/50
# 56/56 [==============================] - 5s 80ms/step - loss: 1.9490 - accuracy: 0.3569 - val_loss: 2.1185 - val_accuracy: 0.3041
# Epoch 48/50
# 56/56 [==============================] - 4s 80ms/step - loss: 1.9363 - accuracy: 0.3668 - val_loss: 2.2364 - val_accuracy: 0.2764
# Epoch 49/50
# 56/56 [==============================] - 5s 81ms/step - loss: 1.9416 - accuracy: 0.3685 - val_loss: 2.0698 - val_accuracy: 0.3438
# Epoch 50/50
# 56/56 [==============================] - 5s 81ms/step - loss: 1.9009 - accuracy: 0.3827 - val_loss: 2.0889 - val_accuracy: 0.3233
# 13/13 [==============================] - 1s 63ms/step - loss: 2.0618 - accuracy: 0.3293

# %% [markdown]
# #5. Visualización del rendimiento

# %%
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(15,13))

# precision con batch = 8
plt.subplot(2, 1, 1)
plt.plot(range(EPOCHS), accs[0], label='Rendimiento train (accuracy), batch = 8')
plt.plot(range(EPOCHS), val_accs[0], label='Rendimiento validacion (accuracy), batch = 8')
plt.plot(range(EPOCHS), accs[1], label='Rendimiento train (accuracy), batch = 16')
plt.plot(range(EPOCHS), val_accs[1], label='Rendimiento validacion (accuracy), batch = 16')
plt.plot(range(EPOCHS), accs[2], label='Rendimiento train (accuracy), batch = 32')
plt.plot(range(EPOCHS), val_accs[2], label='Rendimiento validacion (accuracy), batch = 32')
plt.plot(range(EPOCHS), accs[3], label='Rendimiento train (accuracy), batch = 64')
plt.plot(range(EPOCHS), val_accs[3], label='Rendimiento validacion (accuracy), batch = 64')
plt.legend(loc='upper left')
plt.title('Training and Validation Accuracy')
plt.xlabel('# epoca')
plt.ylabel('Precision')
plt.tight_layout()

# perdidas con batch = 8
plt.subplot(2, 1, 2)
plt.plot(range(EPOCHS), losses[0], label='Pérdidas entrenamiento (Loss), batch = 8')
plt.plot(range(EPOCHS), val_losses[0], label='Pérdidas validacion (Loss), batch = 8')
plt.plot(range(EPOCHS), losses[1], label='Pérdidas entrenamiento (Loss), batch = 16')
plt.plot(range(EPOCHS), val_losses[1], label='Pérdidas validacion (Loss), batch = 16')
plt.plot(range(EPOCHS), losses[2], label='Pérdidas entrenamiento (Loss), batch = 32')
plt.plot(range(EPOCHS), val_losses[2], label='Pérdidas validacion (Loss), batch = 32')
plt.plot(range(EPOCHS), losses[3], label='Pérdidas entrenamiento (Loss), batch = 64')
plt.plot(range(EPOCHS), val_losses[3], label='Pérdidas validacion (Loss), batch = 64')
plt.legend(loc='upper left')
plt.title('Training and Validation Loss')
plt.xlabel('# epoca')
plt.ylabel('Perdida')
plt.tight_layout()


plt.show()

# %% [markdown]
# # Mostramos únicamente los resultados con batch_size = 32, ya que hemos considerado que es el mejor valor.

# %%
fig = plt.figure(figsize=(15,13))

# precision con batch = 32
plt.subplot(2, 1, 1)
plt.plot(range(EPOCHS), accs[2], label='Rendimiento train (accuracy)')
plt.plot(range(EPOCHS), val_accs[2], label='Rendimiento validacion (accuracy)')
plt.legend(loc='upper left')
plt.title('Training and Validation Accuracy, batch_size = 32')
plt.xlabel('# epoca')
plt.ylabel('Precision')
plt.tight_layout()

# perdidas con batch = 32
plt.subplot(2, 1, 2)
plt.plot(range(EPOCHS), losses[2], label='Pérdidas entrenamiento (Loss)')
plt.plot(range(EPOCHS), val_losses[2], label='Pérdidas validacion (Loss)')
plt.legend(loc='upper left')
plt.title('Training and Validation Loss, batch_size = 32')
plt.xlabel('# epoca')
plt.ylabel('Perdida')
plt.tight_layout()


plt.show()

# %% [markdown]
# #6.Guardar resultados

# %%
#guardar el modelo de red obtenido
#https://www.tensorflow.org/api_docs/python/tf/keras/Model
#https://www.tensorflow.org/tutorials/keras/save_and_load
os.chdir(dwld_dir)  
save_dir = dwld_dir + '/my_models'
subprocess.call(["mkdir","-p",save_dir])  # crear directorio para guardar modelo
model.save(
    save_dir,
    overwrite=True,
    include_optimizer=True,
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/dwld_dir/my_models/assets
