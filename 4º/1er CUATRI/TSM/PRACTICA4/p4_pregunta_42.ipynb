# %% [markdown]
# # Notebook para la pregunta 4.2 sobre el reconocimiento de escenas con Redes Convolucionales Neuronales

# %% [markdown]
# # 1.Preparación del entorno de trabajo como en los notebooks anteriores

# %%
#%%capture
#%tensorflow_version 2.x
# !pip install tensorflow==2.3.0
import tensorflow as tf
import os, subprocess
# !python --version                     # mostrar version de python
print('Tensorflow ' + tf.__version__) # mostrar version tensorflow
# Out:
# Collecting tensorflow==2.3.0
#   Downloading tensorflow-2.3.0-cp37-cp37m-manylinux2010_x86_64.whl (320.4 MB)
#      |████████████████████████████████| 320.4 MB 46 kB/s
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 30.9 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.0)
# Requirement already satisfied: scipy==1.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.4.1)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.6.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.12.0)
# Collecting numpy<1.19.0,>=1.16.0
#   Downloading numpy-1.18.5-cp37-cp37m-manylinux1_x86_64.whl (20.1 MB)
#      |████████████████████████████████| 20.1 MB 1.3 MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.37.0)
# Collecting tensorflow-estimator<2.4.0,>=2.3.0
#   Downloading tensorflow_estimator-2.3.0-py2.py3-none-any.whl (459 kB)
#      |████████████████████████████████| 459 kB 25.9 MB/s
# Requirement already satisfied: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (0.2.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.42.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.17.3)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.13.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (1.15.0)
# Requirement already satisfied: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (2.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.3.0) (3.3.0)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.35.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (57.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.8.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.10.0.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow==2.3.0) (3.1.1)
# Installing collected packages: numpy, tensorflow-estimator, h5py, gast, tensorflow
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed gast-0.3.3 h5py-2.10.0 numpy-1.18.5 tensorflow-2.3.0 tensorflow-estimator-2.3.0
# Python 3.7.12
# Tensorflow 2.3.0

# %% [markdown]
# # 2.Creación y almacenamiento de los datos

# %%
import os, subprocess

# Montar Google Drive y crear carpetas
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

work_dir = '/content/work_dir'                    # directorio de trabajo en local (mas rapido)
dwld_dir = '/content/gdrive/My Drive/dwld_dir'    # directorio de descarga en Google drive personal
subprocess.call(["mkdir","-p",work_dir])          # crear directorio para trabajo
subprocess.call(["mkdir","-p",dwld_dir+'/dataset/'])  # crear directorio para dataset

os.chdir(dwld_dir+'/dataset/')                        # posicionarse en el directorio
# Descargar dataset scenes15 si no esta disponible
if os.path.isfile('./dataset_scenes15.zip') == False: 
  # !wget http://www-vpu.eps.uam.es/~jcs/tsv/dataset_scenes15.zip 
  
# Copiar el dataset al directorio local (mayor velocidad de lectura que en Gdrive)
# !cp /content/gdrive/My\ Drive/dwld_dir/dataset/dataset_scenes15.zip /content/work_dir/

os.chdir(work_dir)                        # posicionarse en el directorio
if os.path.isdir('./scenes15') == False: 
  # !unzip -o -q dataset_scenes15.zip -d .

print('El dataset se encuentra descargado en el directorio {} \ny descomprimido en el directorio {} (usado para lectura de datos)'.format(dwld_dir, work_dir))
# Out:
# Mounted at /content/gdrive
# El dataset se encuentra descargado en el directorio /content/gdrive/My Drive/dwld_dir
# y descomprimido en el directorio /content/work_dir (usado para lectura de datos)

# %% [markdown]
# # 3.Seleccionamos Hardware como en ejemplos previos

# %%
import tensorflow as tf
import time

print("Num CPUs disponibles: ", len(tf.config.experimental.list_physical_devices('CPU')))
print("Num GPUs disponibles: ", len(tf.config.experimental.list_physical_devices('GPU')))

time1 = time.time() # medida de tiempo

# ejecutar en CPU
with tf.device('/CPU:0'):
  random_image_cpu = tf.random.normal((100, 100, 100, 3))
  net_cpu = tf.keras.layers.Conv2D(128, 7)(random_image_cpu)

time2 = time.time() # medida de tiempo

# ejecutar en GPU
with tf.device('/device:GPU:0'):
  random_image_cpu = tf.random.normal((100, 100, 100, 3))
  net_cpu = tf.keras.layers.Conv2D(128, 7)(random_image_cpu)

time3 = time.time() # medida de tiempo
print('Tiempo ejecución CPU {} secs y GPU {} secs' .format(time2-time1, time3-time2))
print('Ejecute varias veces este bloque de código pues la primera vez no observará diferencias debido a que se deben inicializar los registros para la CPU y GPU')
# Out:
# Num CPUs disponibles:  1
# Num GPUs disponibles:  1
# Tiempo ejecución CPU 1.7296078205108643 secs y GPU 3.372316598892212 secs
# Ejecute varias veces este bloque de código pues la primera vez no observará diferencias debido a que se deben inicializar los registros para la CPU y GPU

# %% [markdown]
# # 4.Crear iterador para los datos del dataset, definición del modelo, optimización de parámetros, entrenamiento y clasificación

# %%
import tensorflow as tf
import pathlib
import numpy as np
import tensorflow.keras.layers as layers
import tensorflow.keras.models as models
import tensorflow.keras.optimizers as optimizers
import matplotlib.pyplot as plt

img_sizes = [32, 64, 128, 224]
accs = []
val_accs = []
losses = []
val_losses = []

for img_size in img_sizes:

  dataset_dir = pathlib.Path(work_dir + '/scenes15/')

  # Obtener etiquetas de clase y numero de clases
  CLASS_NAMES = np.array([item.name for item in dataset_dir.glob('*')]) #clases son subdirectorios de '/train/'
  NUM_CLASSES = len(CLASS_NAMES) # numero total de clases
 
  # Crear ImageDataGenerator convirtiendo de uint8 a float32 en el rango [0,1].
  img_gen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, validation_split=0.20)

  # Obtenemos un iterador sobre los datos de entrenamiento del dataset
  # aplicando el ImageDataGenerator creado anteriormente
  BATCH_SIZE = 32 # numero de elementos procesados conjuntamente en cada iteracion
  IMG_HEIGHT = img_size
  IMG_WIDTH = img_size
  IMG_CHANNELS = 3

  train_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',                                                     
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE, 
                                            subset="training",                                         
                                            shuffle=True,
                                            seed=0)

  test_data_gen = img_gen.flow_from_directory(directory=str(dataset_dir),
                                            target_size=(IMG_HEIGHT, IMG_WIDTH),
                                            color_mode='rgb',                                                     
                                            classes = list(CLASS_NAMES),
                                            class_mode='categorical',
                                            batch_size=BATCH_SIZE,
                                            subset="validation",
                                            shuffle=True,
                                            seed=0)
  
  # definir modelo de red
  model = models.Sequential()

  # incluir capa convolucional C1
  model.add(layers.Conv2D(filters=6, 
                          kernel_size=(3, 3), 
                          strides = (1,1),
                          padding = 'valid',
                          activation='relu', 
                          input_shape=(IMG_HEIGHT,IMG_WIDTH,IMG_CHANNELS)))

  # incluir average pooling S2
  model.add(layers.AveragePooling2D())

  # incluir capa convolucional C3
  model.add(layers.Conv2D(filters=16, 
                          kernel_size=(3, 3),
                          strides = (1,1),
                          padding = 'valid', 
                          activation='relu'))

  # incluir average pooling S4
  model.add(layers.AveragePooling2D())

  # convertir el volumen de datos en vector fila para conectarlo con capa FC
  model.add(layers.Flatten())

  # incluir fully convolutional F5
  model.add(layers.Dense(units=120, activation='relu'))

  # incluir fully convolutional F6
  model.add(layers.Dense(units=84, activation='relu'))

  # incluir salida OUTPUT
  model.add(layers.Dense(units=NUM_CLASSES, activation = 'softmax'))

  LEARNING_RATE = 0.01 # factor de aprendizaje
  model.compile(optimizer=optimizers.SGD(lr=LEARNING_RATE),            
            loss='categorical_crossentropy',            
            metrics=['accuracy'])
  
  EPOCHS = 50 # numero de epocas para entrenamiento

  #si tiene problemas al ejecutar con la GPU, 
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    history = model.fit_generator(
        generator=train_data_gen,          
        steps_per_epoch=train_data_gen.n // BATCH_SIZE,      
        validation_data=test_data_gen,
        validation_steps=test_data_gen.n // BATCH_SIZE,
        epochs=EPOCHS,
        verbose=1     
    )  

  #si tiene problemas al ejecutar con la GPU, 
  # descomente la siguiente linea para utilizar la CPU
  # y comente la linea que selecciona la GPU
  #with tf.device('/CPU:0'):
  with tf.device('/GPU:0'):
    test_loss, test_acc = model.evaluate_generator(generator=test_data_gen, 
                                                  steps = test_data_gen.n // BATCH_SIZE, 
                                                  verbose=1)
  accs.append(history.history['accuracy']) 
  val_accs.append(history.history['val_accuracy'])
  losses.append(history.history['loss'])
  val_losses.append(history.history['val_loss'])
# Out:
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# WARNING:tensorflow:From <ipython-input-3-26a1fcab3c16>:107: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 112/112 [==============================] - 5s 46ms/step - loss: 2.7063 - accuracy: 0.0640 - val_loss: 2.7021 - val_accuracy: 0.0787
# Epoch 2/50
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6991 - accuracy: 0.0803 - val_loss: 2.6961 - val_accuracy: 0.0984
# Epoch 3/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6936 - accuracy: 0.0879 - val_loss: 2.6898 - val_accuracy: 0.1088
# Epoch 4/50
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6877 - accuracy: 0.1011 - val_loss: 2.6844 - val_accuracy: 0.1076
# Epoch 5/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6803 - accuracy: 0.1096 - val_loss: 2.6782 - val_accuracy: 0.1134
# Epoch 6/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.6692 - accuracy: 0.1084 - val_loss: 2.6659 - val_accuracy: 0.1111
# Epoch 7/50
# 112/112 [==============================] - 5s 43ms/step - loss: 2.6506 - accuracy: 0.1160 - val_loss: 2.6523 - val_accuracy: 0.0961
# Epoch 8/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.6191 - accuracy: 0.1188 - val_loss: 2.6214 - val_accuracy: 0.1053
# Epoch 9/50
# 112/112 [==============================] - 5s 40ms/step - loss: 2.5761 - accuracy: 0.1534 - val_loss: 2.6042 - val_accuracy: 0.1238
# Epoch 10/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.5341 - accuracy: 0.1683 - val_loss: 2.5683 - val_accuracy: 0.1296
# Epoch 11/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.4977 - accuracy: 0.1829 - val_loss: 2.5605 - val_accuracy: 0.1481
# Epoch 12/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.4636 - accuracy: 0.1933 - val_loss: 2.5228 - val_accuracy: 0.1493
# Epoch 13/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.4359 - accuracy: 0.2011 - val_loss: 2.5036 - val_accuracy: 0.1875
# Epoch 14/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.3987 - accuracy: 0.2202 - val_loss: 2.4594 - val_accuracy: 0.2072
# Epoch 15/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.3728 - accuracy: 0.2225 - val_loss: 2.4518 - val_accuracy: 0.1863
# Epoch 16/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.3399 - accuracy: 0.2396 - val_loss: 2.4437 - val_accuracy: 0.2188
# Epoch 17/50
# 112/112 [==============================] - 5s 43ms/step - loss: 2.3075 - accuracy: 0.2525 - val_loss: 2.3845 - val_accuracy: 0.2315
# Epoch 18/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.2736 - accuracy: 0.2525 - val_loss: 2.3840 - val_accuracy: 0.2211
# Epoch 19/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.2402 - accuracy: 0.2781 - val_loss: 2.4449 - val_accuracy: 0.1910
# Epoch 20/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.1987 - accuracy: 0.2815 - val_loss: 2.4433 - val_accuracy: 0.2222
# Epoch 21/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.1944 - accuracy: 0.2753 - val_loss: 2.2817 - val_accuracy: 0.2708
# Epoch 22/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.1407 - accuracy: 0.2916 - val_loss: 2.2439 - val_accuracy: 0.2581
# Epoch 23/50
# 112/112 [==============================] - 5s 43ms/step - loss: 2.1275 - accuracy: 0.3034 - val_loss: 2.2384 - val_accuracy: 0.2697
# Epoch 24/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.0743 - accuracy: 0.3211 - val_loss: 2.1613 - val_accuracy: 0.2940
# Epoch 25/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.0750 - accuracy: 0.3270 - val_loss: 2.1795 - val_accuracy: 0.2951
# Epoch 26/50
# 112/112 [==============================] - 5s 42ms/step - loss: 2.0104 - accuracy: 0.3447 - val_loss: 2.2206 - val_accuracy: 0.2708
# Epoch 27/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.9907 - accuracy: 0.3522 - val_loss: 2.0960 - val_accuracy: 0.3137
# Epoch 28/50
# 112/112 [==============================] - 5s 41ms/step - loss: 2.0034 - accuracy: 0.3573 - val_loss: 2.1471 - val_accuracy: 0.2963
# Epoch 29/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.9627 - accuracy: 0.3660 - val_loss: 2.1012 - val_accuracy: 0.3021
# Epoch 30/50
# 112/112 [==============================] - 5s 42ms/step - loss: 1.9226 - accuracy: 0.3795 - val_loss: 2.0899 - val_accuracy: 0.3206
# Epoch 31/50
# 112/112 [==============================] - 5s 42ms/step - loss: 1.8953 - accuracy: 0.3789 - val_loss: 2.0385 - val_accuracy: 0.3299
# Epoch 32/50
# 112/112 [==============================] - 5s 42ms/step - loss: 1.8610 - accuracy: 0.3933 - val_loss: 2.0690 - val_accuracy: 0.3183
# Epoch 33/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.8526 - accuracy: 0.4098 - val_loss: 2.0179 - val_accuracy: 0.3403
# Epoch 34/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.8513 - accuracy: 0.4053 - val_loss: 2.0991 - val_accuracy: 0.3264
# Epoch 35/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.8080 - accuracy: 0.4039 - val_loss: 2.0160 - val_accuracy: 0.3275
# Epoch 36/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.7805 - accuracy: 0.4261 - val_loss: 1.9748 - val_accuracy: 0.3403
# Epoch 37/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.7756 - accuracy: 0.4152 - val_loss: 2.1548 - val_accuracy: 0.2743
# Epoch 38/50
# 112/112 [==============================] - 5s 41ms/step - loss: 1.7774 - accuracy: 0.4202 - val_loss: 1.9892 - val_accuracy: 0.3345
# Epoch 39/50
# 112/112 [==============================] - 5s 42ms/step - loss: 1.7376 - accuracy: 0.4230 - val_loss: 1.9494 - val_accuracy: 0.3553
# Epoch 40/50
# 112/112 [==============================] - 5s 42ms/step - loss: 1.7250 - accuracy: 0.4404 - val_loss: 1.9856 - val_accuracy: 0.3287
# Epoch 41/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.7425 - accuracy: 0.4360 - val_loss: 2.0833 - val_accuracy: 0.3137
# Epoch 42/50
# 112/112 [==============================] - 5s 42ms/step - loss: 1.7181 - accuracy: 0.4542 - val_loss: 2.0011 - val_accuracy: 0.3438
# Epoch 43/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.6949 - accuracy: 0.4537 - val_loss: 1.9626 - val_accuracy: 0.3438
# Epoch 44/50
# 112/112 [==============================] - 5s 42ms/step - loss: 1.6642 - accuracy: 0.4663 - val_loss: 1.9757 - val_accuracy: 0.3634
# Epoch 45/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.6469 - accuracy: 0.4559 - val_loss: 2.1031 - val_accuracy: 0.3229
# Epoch 46/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.6721 - accuracy: 0.4607 - val_loss: 1.9999 - val_accuracy: 0.3507
# Epoch 47/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.6206 - accuracy: 0.4722 - val_loss: 1.9452 - val_accuracy: 0.3808
# Epoch 48/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.5969 - accuracy: 0.4758 - val_loss: 2.0415 - val_accuracy: 0.3438
# Epoch 49/50
# 112/112 [==============================] - 5s 42ms/step - loss: 1.6059 - accuracy: 0.4719 - val_loss: 1.9409 - val_accuracy: 0.3565
# Epoch 50/50
# 112/112 [==============================] - 5s 42ms/step - loss: 1.5835 - accuracy: 0.4806 - val_loss: 1.8928 - val_accuracy: 0.3738
# WARNING:tensorflow:From <ipython-input-3-26a1fcab3c16>:117: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# 27/27 [==============================] - 1s 34ms/step - loss: 1.8891 - accuracy: 0.3704
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/50
# 112/112 [==============================] - 5s 47ms/step - loss: 2.7066 - accuracy: 0.0728 - val_loss: 2.7032 - val_accuracy: 0.0984
# Epoch 2/50
# 112/112 [==============================] - 5s 46ms/step - loss: 2.6990 - accuracy: 0.0978 - val_loss: 2.6967 - val_accuracy: 0.0880
# Epoch 3/50
# 112/112 [==============================] - 5s 45ms/step - loss: 2.6905 - accuracy: 0.0899 - val_loss: 2.6870 - val_accuracy: 0.1053
# Epoch 4/50
# 112/112 [==============================] - 5s 45ms/step - loss: 2.6768 - accuracy: 0.1087 - val_loss: 2.6718 - val_accuracy: 0.0938
# Epoch 5/50
# 112/112 [==============================] - 5s 45ms/step - loss: 2.6515 - accuracy: 0.1180 - val_loss: 2.6401 - val_accuracy: 0.1366
# Epoch 6/50
# 112/112 [==============================] - 5s 44ms/step - loss: 2.5976 - accuracy: 0.1553 - val_loss: 2.5828 - val_accuracy: 0.1817
# Epoch 7/50
# 112/112 [==============================] - 5s 45ms/step - loss: 2.5016 - accuracy: 0.1938 - val_loss: 2.4960 - val_accuracy: 0.1968
# Epoch 8/50
# 112/112 [==============================] - 5s 45ms/step - loss: 2.4290 - accuracy: 0.2087 - val_loss: 2.5122 - val_accuracy: 0.1852
# Epoch 9/50
# 112/112 [==============================] - 5s 45ms/step - loss: 2.3614 - accuracy: 0.2315 - val_loss: 2.4280 - val_accuracy: 0.2060
# Epoch 10/50
# 112/112 [==============================] - 5s 46ms/step - loss: 2.3084 - accuracy: 0.2508 - val_loss: 2.4496 - val_accuracy: 0.2025
# Epoch 11/50
# 112/112 [==============================] - 5s 45ms/step - loss: 2.2577 - accuracy: 0.2677 - val_loss: 2.3517 - val_accuracy: 0.2350
# Epoch 12/50
# 112/112 [==============================] - 5s 43ms/step - loss: 2.2289 - accuracy: 0.2683 - val_loss: 2.5222 - val_accuracy: 0.2002
# Epoch 13/50
# 112/112 [==============================] - 5s 43ms/step - loss: 2.1697 - accuracy: 0.2837 - val_loss: 2.3333 - val_accuracy: 0.2269
# Epoch 14/50
# 112/112 [==============================] - 5s 43ms/step - loss: 2.1328 - accuracy: 0.3039 - val_loss: 2.2950 - val_accuracy: 0.2581
# Epoch 15/50
# 112/112 [==============================] - 5s 43ms/step - loss: 2.0640 - accuracy: 0.3244 - val_loss: 2.2354 - val_accuracy: 0.2801
# Epoch 16/50
# 112/112 [==============================] - 5s 43ms/step - loss: 2.0666 - accuracy: 0.3256 - val_loss: 2.1686 - val_accuracy: 0.2998
# Epoch 17/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.9677 - accuracy: 0.3643 - val_loss: 2.1115 - val_accuracy: 0.2951
# Epoch 18/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.9659 - accuracy: 0.3629 - val_loss: 2.2285 - val_accuracy: 0.2986
# Epoch 19/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.8641 - accuracy: 0.3904 - val_loss: 2.1194 - val_accuracy: 0.3102
# Epoch 20/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.8153 - accuracy: 0.3989 - val_loss: 2.0157 - val_accuracy: 0.3461
# Epoch 21/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.7503 - accuracy: 0.4205 - val_loss: 2.0250 - val_accuracy: 0.3380
# Epoch 22/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.7614 - accuracy: 0.4306 - val_loss: 1.9966 - val_accuracy: 0.3380
# Epoch 23/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.6907 - accuracy: 0.4362 - val_loss: 2.2254 - val_accuracy: 0.3044
# Epoch 24/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.6529 - accuracy: 0.4587 - val_loss: 1.9595 - val_accuracy: 0.3657
# Epoch 25/50
# 112/112 [==============================] - 5s 45ms/step - loss: 1.6107 - accuracy: 0.4711 - val_loss: 1.9325 - val_accuracy: 0.3808
# Epoch 26/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.5871 - accuracy: 0.4857 - val_loss: 1.9458 - val_accuracy: 0.3738
# Epoch 27/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.5554 - accuracy: 0.4902 - val_loss: 1.9227 - val_accuracy: 0.3646
# Epoch 28/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.4982 - accuracy: 0.5087 - val_loss: 2.2199 - val_accuracy: 0.3125
# Epoch 29/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.4878 - accuracy: 0.5140 - val_loss: 1.9418 - val_accuracy: 0.3634
# Epoch 30/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.4622 - accuracy: 0.5272 - val_loss: 2.0580 - val_accuracy: 0.3935
# Epoch 31/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.4094 - accuracy: 0.5351 - val_loss: 1.9575 - val_accuracy: 0.3553
# Epoch 32/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.3656 - accuracy: 0.5494 - val_loss: 2.0147 - val_accuracy: 0.3669
# Epoch 33/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.3416 - accuracy: 0.5559 - val_loss: 1.9785 - val_accuracy: 0.3657
# Epoch 34/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.3060 - accuracy: 0.5812 - val_loss: 1.9349 - val_accuracy: 0.3553
# Epoch 35/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.2827 - accuracy: 0.5933 - val_loss: 1.9622 - val_accuracy: 0.3912
# Epoch 36/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.2418 - accuracy: 0.5927 - val_loss: 1.9878 - val_accuracy: 0.3588
# Epoch 37/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.1799 - accuracy: 0.6101 - val_loss: 2.0036 - val_accuracy: 0.3924
# Epoch 38/50
# 112/112 [==============================] - 5s 43ms/step - loss: 1.1425 - accuracy: 0.6174 - val_loss: 2.0738 - val_accuracy: 0.3646
# Epoch 39/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.1802 - accuracy: 0.6219 - val_loss: 2.0478 - val_accuracy: 0.3715
# Epoch 40/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.0864 - accuracy: 0.6371 - val_loss: 2.0222 - val_accuracy: 0.3750
# Epoch 41/50
# 112/112 [==============================] - 5s 45ms/step - loss: 1.0267 - accuracy: 0.6537 - val_loss: 2.4333 - val_accuracy: 0.3218
# Epoch 42/50
# 112/112 [==============================] - 5s 44ms/step - loss: 1.0343 - accuracy: 0.6497 - val_loss: 2.1987 - val_accuracy: 0.3449
# Epoch 43/50
# 112/112 [==============================] - 5s 44ms/step - loss: 0.9859 - accuracy: 0.6699 - val_loss: 2.1034 - val_accuracy: 0.3843
# Epoch 44/50
# 112/112 [==============================] - 5s 45ms/step - loss: 0.9170 - accuracy: 0.6938 - val_loss: 2.3397 - val_accuracy: 0.3530
# Epoch 45/50
# 112/112 [==============================] - 5s 47ms/step - loss: 0.9247 - accuracy: 0.7110 - val_loss: 2.1460 - val_accuracy: 0.3947
# Epoch 46/50
# 112/112 [==============================] - 5s 46ms/step - loss: 0.8562 - accuracy: 0.7163 - val_loss: 2.1566 - val_accuracy: 0.3854
# Epoch 47/50
# 112/112 [==============================] - 5s 46ms/step - loss: 0.7987 - accuracy: 0.7416 - val_loss: 2.2810 - val_accuracy: 0.3681
# Epoch 48/50
# 112/112 [==============================] - 5s 46ms/step - loss: 0.7738 - accuracy: 0.7500 - val_loss: 2.3182 - val_accuracy: 0.3634
# Epoch 49/50
# 112/112 [==============================] - 5s 45ms/step - loss: 0.7608 - accuracy: 0.7506 - val_loss: 2.2532 - val_accuracy: 0.3889
# Epoch 50/50
# 112/112 [==============================] - 5s 45ms/step - loss: 0.7414 - accuracy: 0.7621 - val_loss: 2.1775 - val_accuracy: 0.3704
# 27/27 [==============================] - 1s 34ms/step - loss: 2.1913 - accuracy: 0.3657
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/50
# 112/112 [==============================] - 7s 60ms/step - loss: 2.6852 - accuracy: 0.1070 - val_loss: 2.6689 - val_accuracy: 0.1088
# Epoch 2/50
# 112/112 [==============================] - 6s 58ms/step - loss: 2.6083 - accuracy: 0.1368 - val_loss: 2.5837 - val_accuracy: 0.1458
# Epoch 3/50
# 112/112 [==============================] - 6s 57ms/step - loss: 2.5048 - accuracy: 0.1787 - val_loss: 2.5292 - val_accuracy: 0.1620
# Epoch 4/50
# 112/112 [==============================] - 6s 57ms/step - loss: 2.4141 - accuracy: 0.2090 - val_loss: 2.4430 - val_accuracy: 0.1921
# Epoch 5/50
# 112/112 [==============================] - 6s 56ms/step - loss: 2.3386 - accuracy: 0.2315 - val_loss: 2.4549 - val_accuracy: 0.2280
# Epoch 6/50
# 112/112 [==============================] - 6s 54ms/step - loss: 2.2667 - accuracy: 0.2649 - val_loss: 2.3753 - val_accuracy: 0.2396
# Epoch 7/50
# 112/112 [==============================] - 6s 54ms/step - loss: 2.2111 - accuracy: 0.2823 - val_loss: 2.3650 - val_accuracy: 0.2326
# Epoch 8/50
# 112/112 [==============================] - 6s 56ms/step - loss: 2.1383 - accuracy: 0.3031 - val_loss: 2.3609 - val_accuracy: 0.2569
# Epoch 9/50
# 112/112 [==============================] - 6s 55ms/step - loss: 2.0825 - accuracy: 0.3317 - val_loss: 2.3020 - val_accuracy: 0.2569
# Epoch 10/50
# 112/112 [==============================] - 6s 56ms/step - loss: 2.0514 - accuracy: 0.3427 - val_loss: 2.3377 - val_accuracy: 0.2500
# Epoch 11/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.9591 - accuracy: 0.3688 - val_loss: 2.2952 - val_accuracy: 0.2708
# Epoch 12/50
# 112/112 [==============================] - 6s 55ms/step - loss: 1.8944 - accuracy: 0.3902 - val_loss: 2.1686 - val_accuracy: 0.2940
# Epoch 13/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.8289 - accuracy: 0.4261 - val_loss: 2.2475 - val_accuracy: 0.2894
# Epoch 14/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.7447 - accuracy: 0.4393 - val_loss: 2.2066 - val_accuracy: 0.2951
# Epoch 15/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.6644 - accuracy: 0.4626 - val_loss: 2.0581 - val_accuracy: 0.3380
# Epoch 16/50
# 112/112 [==============================] - 6s 57ms/step - loss: 1.5672 - accuracy: 0.5017 - val_loss: 2.1503 - val_accuracy: 0.3148
# Epoch 17/50
# 112/112 [==============================] - 6s 54ms/step - loss: 1.5146 - accuracy: 0.5160 - val_loss: 2.0553 - val_accuracy: 0.3438
# Epoch 18/50
# 112/112 [==============================] - 6s 55ms/step - loss: 1.4276 - accuracy: 0.5396 - val_loss: 2.0330 - val_accuracy: 0.3507
# Epoch 19/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.3520 - accuracy: 0.5598 - val_loss: 2.0700 - val_accuracy: 0.3576
# Epoch 20/50
# 112/112 [==============================] - 6s 56ms/step - loss: 1.2589 - accuracy: 0.5843 - val_loss: 2.1983 - val_accuracy: 0.3657
# Epoch 21/50
# 112/112 [==============================] - 6s 55ms/step - loss: 1.2079 - accuracy: 0.6101 - val_loss: 2.1670 - val_accuracy: 0.3646
# Epoch 22/50
# 112/112 [==============================] - 6s 55ms/step - loss: 1.1235 - accuracy: 0.6292 - val_loss: 2.2127 - val_accuracy: 0.3681
# Epoch 23/50
# 112/112 [==============================] - 6s 55ms/step - loss: 1.0205 - accuracy: 0.6593 - val_loss: 3.0984 - val_accuracy: 0.2361
# Epoch 24/50
# 112/112 [==============================] - 6s 55ms/step - loss: 0.9831 - accuracy: 0.6823 - val_loss: 2.3725 - val_accuracy: 0.3438
# Epoch 25/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.8995 - accuracy: 0.7053 - val_loss: 2.7193 - val_accuracy: 0.3310
# Epoch 26/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.8165 - accuracy: 0.7289 - val_loss: 2.3706 - val_accuracy: 0.3322
# Epoch 27/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.7415 - accuracy: 0.7649 - val_loss: 2.4784 - val_accuracy: 0.3403
# Epoch 28/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.6814 - accuracy: 0.7812 - val_loss: 2.9302 - val_accuracy: 0.3009
# Epoch 29/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.6072 - accuracy: 0.8107 - val_loss: 2.4651 - val_accuracy: 0.3623
# Epoch 30/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.5469 - accuracy: 0.8329 - val_loss: 2.4876 - val_accuracy: 0.4016
# Epoch 31/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.4842 - accuracy: 0.8545 - val_loss: 2.5097 - val_accuracy: 0.3808
# Epoch 32/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.4439 - accuracy: 0.8677 - val_loss: 2.5084 - val_accuracy: 0.3449
# Epoch 33/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.3924 - accuracy: 0.8820 - val_loss: 2.6708 - val_accuracy: 0.3773
# Epoch 34/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.2917 - accuracy: 0.9177 - val_loss: 3.0216 - val_accuracy: 0.3750
# Epoch 35/50
# 112/112 [==============================] - 6s 56ms/step - loss: 0.2617 - accuracy: 0.9272 - val_loss: 3.0549 - val_accuracy: 0.3507
# Epoch 36/50
# 112/112 [==============================] - 6s 55ms/step - loss: 0.2292 - accuracy: 0.9357 - val_loss: 3.2639 - val_accuracy: 0.3472
# Epoch 37/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.1985 - accuracy: 0.9427 - val_loss: 3.1626 - val_accuracy: 0.3970
# Epoch 38/50
# 112/112 [==============================] - 6s 55ms/step - loss: 0.2937 - accuracy: 0.9331 - val_loss: 3.0235 - val_accuracy: 0.3634
# Epoch 39/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.1821 - accuracy: 0.9548 - val_loss: 2.9821 - val_accuracy: 0.3819
# Epoch 40/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.1164 - accuracy: 0.9722 - val_loss: 3.2269 - val_accuracy: 0.3912
# Epoch 41/50
# 112/112 [==============================] - 6s 53ms/step - loss: 0.1144 - accuracy: 0.9702 - val_loss: 3.3992 - val_accuracy: 0.3924
# Epoch 42/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.0862 - accuracy: 0.9809 - val_loss: 3.4842 - val_accuracy: 0.3947
# Epoch 43/50
# 112/112 [==============================] - 6s 53ms/step - loss: 0.0600 - accuracy: 0.9862 - val_loss: 3.5794 - val_accuracy: 0.3912
# Epoch 44/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.1136 - accuracy: 0.9711 - val_loss: 3.5149 - val_accuracy: 0.3808
# Epoch 45/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.0464 - accuracy: 0.9921 - val_loss: 4.1032 - val_accuracy: 0.3623
# Epoch 46/50
# 112/112 [==============================] - 6s 55ms/step - loss: 0.0612 - accuracy: 0.9865 - val_loss: 3.6150 - val_accuracy: 0.3912
# Epoch 47/50
# 112/112 [==============================] - 6s 55ms/step - loss: 0.0530 - accuracy: 0.9888 - val_loss: 3.9368 - val_accuracy: 0.3704
# Epoch 48/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.0349 - accuracy: 0.9935 - val_loss: 4.0934 - val_accuracy: 0.3889
# Epoch 49/50
# 112/112 [==============================] - 6s 54ms/step - loss: 0.0331 - accuracy: 0.9949 - val_loss: 3.9786 - val_accuracy: 0.3912
# Epoch 50/50
# 112/112 [==============================] - 6s 55ms/step - loss: 0.0295 - accuracy: 0.9941 - val_loss: 3.9217 - val_accuracy: 0.3935
# 27/27 [==============================] - 1s 42ms/step - loss: 3.9523 - accuracy: 0.3947
# Found 3592 images belonging to 15 classes.
# Found 893 images belonging to 15 classes.
# Epoch 1/50
# 112/112 [==============================] - 10s 87ms/step - loss: 2.7053 - accuracy: 0.1051 - val_loss: 2.7020 - val_accuracy: 0.1134
# Epoch 2/50
# 112/112 [==============================] - 10s 85ms/step - loss: 2.6987 - accuracy: 0.1138 - val_loss: 2.6946 - val_accuracy: 0.1354
# Epoch 3/50
# 112/112 [==============================] - 9s 85ms/step - loss: 2.6902 - accuracy: 0.1096 - val_loss: 2.6876 - val_accuracy: 0.0729
# Epoch 4/50
# 112/112 [==============================] - 9s 85ms/step - loss: 2.6806 - accuracy: 0.1079 - val_loss: 2.6751 - val_accuracy: 0.1285
# Epoch 5/50
# 112/112 [==============================] - 9s 84ms/step - loss: 2.6667 - accuracy: 0.1138 - val_loss: 2.6583 - val_accuracy: 0.1331
# Epoch 6/50
# 112/112 [==============================] - 9s 84ms/step - loss: 2.6405 - accuracy: 0.1213 - val_loss: 2.6213 - val_accuracy: 0.1655
# Epoch 7/50
# 112/112 [==============================] - 9s 85ms/step - loss: 2.6031 - accuracy: 0.1368 - val_loss: 2.5653 - val_accuracy: 0.1574
# Epoch 8/50
# 112/112 [==============================] - 10s 86ms/step - loss: 2.5668 - accuracy: 0.1593 - val_loss: 2.5063 - val_accuracy: 0.1806
# Epoch 9/50
# 112/112 [==============================] - 9s 84ms/step - loss: 2.5446 - accuracy: 0.1694 - val_loss: 2.5465 - val_accuracy: 0.2141
# Epoch 10/50
# 112/112 [==============================] - 9s 85ms/step - loss: 2.5163 - accuracy: 0.1801 - val_loss: 2.3996 - val_accuracy: 0.2222
# Epoch 11/50
# 112/112 [==============================] - 9s 84ms/step - loss: 2.3641 - accuracy: 0.2340 - val_loss: 2.2874 - val_accuracy: 0.2512
# Epoch 12/50
# 112/112 [==============================] - 9s 84ms/step - loss: 2.2029 - accuracy: 0.2674 - val_loss: 2.2121 - val_accuracy: 0.2743
# Epoch 13/50
# 112/112 [==============================] - 9s 84ms/step - loss: 2.1131 - accuracy: 0.3031 - val_loss: 2.1678 - val_accuracy: 0.2905
# Epoch 14/50
# 112/112 [==============================] - 10s 85ms/step - loss: 2.0037 - accuracy: 0.3371 - val_loss: 2.0784 - val_accuracy: 0.3021
# Epoch 15/50
# 112/112 [==============================] - 10s 85ms/step - loss: 1.8804 - accuracy: 0.3857 - val_loss: 2.1308 - val_accuracy: 0.3113
# Epoch 16/50
# 112/112 [==============================] - 10s 85ms/step - loss: 1.7953 - accuracy: 0.4138 - val_loss: 2.0995 - val_accuracy: 0.3264
# Epoch 17/50
# 112/112 [==============================] - 10s 85ms/step - loss: 1.6857 - accuracy: 0.4506 - val_loss: 2.0431 - val_accuracy: 0.3484
# Epoch 18/50
# 112/112 [==============================] - 10s 86ms/step - loss: 1.5439 - accuracy: 0.5098 - val_loss: 2.0692 - val_accuracy: 0.3310
# Epoch 19/50
# 112/112 [==============================] - 10s 88ms/step - loss: 1.4417 - accuracy: 0.5447 - val_loss: 2.2135 - val_accuracy: 0.3299
# Epoch 20/50
# 112/112 [==============================] - 10s 91ms/step - loss: 1.2737 - accuracy: 0.6022 - val_loss: 2.1493 - val_accuracy: 0.3299
# Epoch 21/50
# 112/112 [==============================] - 10s 91ms/step - loss: 1.0844 - accuracy: 0.6629 - val_loss: 2.2664 - val_accuracy: 0.3391
# Epoch 22/50
# 112/112 [==============================] - 10s 91ms/step - loss: 0.9416 - accuracy: 0.7087 - val_loss: 2.4298 - val_accuracy: 0.3322
# Epoch 23/50
# 112/112 [==============================] - 10s 90ms/step - loss: 0.7214 - accuracy: 0.7817 - val_loss: 2.5127 - val_accuracy: 0.3044
# Epoch 24/50
# 112/112 [==============================] - 10s 90ms/step - loss: 0.6116 - accuracy: 0.8239 - val_loss: 2.6117 - val_accuracy: 0.3218
# Epoch 25/50
# 112/112 [==============================] - 10s 90ms/step - loss: 0.4784 - accuracy: 0.8685 - val_loss: 2.6366 - val_accuracy: 0.2870
# Epoch 26/50
# 112/112 [==============================] - 10s 91ms/step - loss: 0.2870 - accuracy: 0.9385 - val_loss: 2.9659 - val_accuracy: 0.3356
# Epoch 27/50
# 112/112 [==============================] - 10s 92ms/step - loss: 0.2334 - accuracy: 0.9486 - val_loss: 2.8979 - val_accuracy: 0.3449
# Epoch 28/50
# 112/112 [==============================] - 10s 92ms/step - loss: 0.1339 - accuracy: 0.9733 - val_loss: 3.2278 - val_accuracy: 0.3484
# Epoch 29/50
# 112/112 [==============================] - 10s 91ms/step - loss: 0.0870 - accuracy: 0.9865 - val_loss: 3.3970 - val_accuracy: 0.3368
# Epoch 30/50
# 112/112 [==============================] - 10s 93ms/step - loss: 0.1901 - accuracy: 0.9685 - val_loss: 3.3252 - val_accuracy: 0.3484
# Epoch 31/50
# 112/112 [==============================] - 10s 93ms/step - loss: 0.0682 - accuracy: 0.9896 - val_loss: 3.4501 - val_accuracy: 0.3414
# Epoch 32/50
# 112/112 [==============================] - 10s 86ms/step - loss: 0.0415 - accuracy: 0.9961 - val_loss: 3.6639 - val_accuracy: 0.3461
# Epoch 33/50
# 112/112 [==============================] - 10s 87ms/step - loss: 0.0318 - accuracy: 0.9966 - val_loss: 3.5995 - val_accuracy: 0.3611
# Epoch 34/50
# 112/112 [==============================] - 10s 87ms/step - loss: 0.0289 - accuracy: 0.9975 - val_loss: 3.7561 - val_accuracy: 0.3611
# Epoch 35/50
# 112/112 [==============================] - 10s 87ms/step - loss: 0.0238 - accuracy: 0.9978 - val_loss: 3.8357 - val_accuracy: 0.3553
# Epoch 36/50
# 112/112 [==============================] - 10s 89ms/step - loss: 0.0187 - accuracy: 0.9989 - val_loss: 3.8585 - val_accuracy: 0.3484
# Epoch 37/50
# 112/112 [==============================] - 10s 88ms/step - loss: 0.1568 - accuracy: 0.9722 - val_loss: 3.6868 - val_accuracy: 0.3414
# Epoch 38/50
# 112/112 [==============================] - 10s 87ms/step - loss: 0.0210 - accuracy: 0.9989 - val_loss: 3.8294 - val_accuracy: 0.3588
# Epoch 39/50
# 112/112 [==============================] - 10s 88ms/step - loss: 0.0178 - accuracy: 0.9986 - val_loss: 3.9356 - val_accuracy: 0.3623
# Epoch 40/50
# 112/112 [==============================] - 10s 88ms/step - loss: 0.0112 - accuracy: 0.9997 - val_loss: 4.0335 - val_accuracy: 0.3507
# Epoch 41/50
# 112/112 [==============================] - 10s 89ms/step - loss: 0.0121 - accuracy: 0.9994 - val_loss: 4.0779 - val_accuracy: 0.3611
# Epoch 42/50
# 112/112 [==============================] - 10s 87ms/step - loss: 0.0095 - accuracy: 0.9997 - val_loss: 4.1601 - val_accuracy: 0.3519
# Epoch 43/50
# 112/112 [==============================] - 10s 87ms/step - loss: 0.2046 - accuracy: 0.9657 - val_loss: 3.8065 - val_accuracy: 0.3530
# Epoch 44/50
# 112/112 [==============================] - 10s 87ms/step - loss: 0.0484 - accuracy: 0.9916 - val_loss: 3.8952 - val_accuracy: 0.3403
# Epoch 45/50
# 112/112 [==============================] - 10s 87ms/step - loss: 0.0134 - accuracy: 0.9994 - val_loss: 4.0801 - val_accuracy: 0.3461
# Epoch 46/50
# 112/112 [==============================] - 10s 87ms/step - loss: 0.0108 - accuracy: 0.9992 - val_loss: 4.1500 - val_accuracy: 0.3588
# Epoch 47/50
# 112/112 [==============================] - 10s 86ms/step - loss: 0.0479 - accuracy: 0.9904 - val_loss: 3.8565 - val_accuracy: 0.3507
# Epoch 48/50
# 112/112 [==============================] - 10s 87ms/step - loss: 0.0236 - accuracy: 0.9966 - val_loss: 4.0624 - val_accuracy: 0.3623
# Epoch 49/50
# 112/112 [==============================] - 10s 85ms/step - loss: 0.0090 - accuracy: 0.9994 - val_loss: 4.1605 - val_accuracy: 0.3611
# Epoch 50/50
# 112/112 [==============================] - 10s 85ms/step - loss: 0.0081 - accuracy: 0.9994 - val_loss: 4.2676 - val_accuracy: 0.3542
# 27/27 [==============================] - 2s 62ms/step - loss: 4.2132 - accuracy: 0.3600

# %% [markdown]
# # 5. Visualización del rendimiento

# %%
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(15,13))

plt.subplot(2, 1, 1)
plt.plot(range(EPOCHS), accs[0], label='Rendimiento train (accuracy), img_size = 32')
plt.plot(range(EPOCHS), val_accs[0], label='Rendimiento validacion (accuracy), img_size = 32')
plt.plot(range(EPOCHS), accs[1], label='Rendimiento train (accuracy), img_size = 64')
plt.plot(range(EPOCHS), val_accs[1], label='Rendimiento validacion (accuracy), img_size = 64')
plt.plot(range(EPOCHS), accs[2], label='Rendimiento train (accuracy), img_size = 128')
plt.plot(range(EPOCHS), val_accs[2], label='Rendimiento validacion (accuracy), img_size = 128')
plt.plot(range(EPOCHS), accs[3], label='Rendimiento train (accuracy), img_size = 224')
plt.plot(range(EPOCHS), val_accs[3], label='Rendimiento validacion (accuracy), img_size = 224')
plt.legend(loc='upper left')
plt.title('Training and Validation Accuracy')
plt.xlabel('# epoca')
plt.ylabel('Precision')
plt.tight_layout()

plt.subplot(2, 1, 2)
plt.plot(range(EPOCHS), losses[0], label='Pérdidas entrenamiento (Loss), img_size = 32')
plt.plot(range(EPOCHS), val_losses[0], label='Pérdidas validacion (Loss), img_size = 32')
plt.plot(range(EPOCHS), losses[1], label='Pérdidas entrenamiento (Loss), img_size = 64')
plt.plot(range(EPOCHS), val_losses[1], label='Pérdidas validacion (Loss), img_size = 64')
plt.plot(range(EPOCHS), losses[2], label='Pérdidas entrenamiento (Loss), img_size = 128')
plt.plot(range(EPOCHS), val_losses[2], label='Pérdidas validacion (Loss), img_size = 128')
plt.plot(range(EPOCHS), losses[3], label='Pérdidas entrenamiento (Loss), img_size = 224')
plt.plot(range(EPOCHS), val_losses[3], label='Pérdidas validacion (Loss), img_size = 224')
plt.legend(loc='upper left')
plt.title('Training and Validation Loss')
plt.xlabel('# epoca')
plt.ylabel('Perdida')
plt.tight_layout()


plt.show()

# %% [markdown]
# # Mostramos las gráficas con img_size = 32, ya que es el valor que mejores resultados ha sacado

# %%
fig = plt.figure(figsize=(15,13))

plt.subplot(2, 1, 1)
plt.plot(range(EPOCHS), accs[0], label='Rendimiento train (accuracy), img_size = 32')
plt.plot(range(EPOCHS), val_accs[0], label='Rendimiento validacion (accuracy), img_size = 32')
plt.legend(loc='upper left')
plt.title('Training and Validation Accuracy, img_size = 32')
plt.xlabel('# epoca')
plt.ylabel('Precision')
plt.tight_layout()

plt.subplot(2, 1, 2)
plt.plot(range(EPOCHS), losses[0], label='Pérdidas entrenamiento (Loss), img_size = 32')
plt.plot(range(EPOCHS), val_losses[0], label='Pérdidas validacion (Loss), img_size = 32')
plt.legend(loc='upper left')
plt.title('Training and Validation Loss, img_size = 32')
plt.xlabel('# epoca')
plt.ylabel('Perdida')
plt.tight_layout()

plt.show()

# %% [markdown]
# #6.Guardar resultados

# %%
#guardar el modelo de red obtenido
#https://www.tensorflow.org/api_docs/python/tf/keras/Model
#https://www.tensorflow.org/tutorials/keras/save_and_load
os.chdir(dwld_dir)  
save_dir = dwld_dir + '/my_models'
subprocess.call(["mkdir","-p",save_dir])  # crear directorio para guardar modelo
model.save(
    save_dir,
    overwrite=True,
    include_optimizer=True,
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: /content/gdrive/My Drive/dwld_dir/my_models/assets
